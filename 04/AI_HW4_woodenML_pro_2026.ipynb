# %% [markdown]
# <a href="https://colab.research.google.com/github/Murcha1990/ML_AI25/blob/main/Hometasks/Pro/AI_HW4_woodenML_pro_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Домашнее задание 4 (pro): древесные алгоритмы**

# %% [markdown]
# ### **Постановка задач**
#
# ### **Домашнее задание состоит из двух подзадач:**
#
# **1. В  разделе 1 ваша задача:**
# -  реализовать свое решающее дерево
# - сравнить его со стандартной имплементацией из sklearn
#
# Функции и классы дерева вы должны оформить в модуль `hw4_code_pro.py`.
#
# **2. В разделе два ваша задача:** решить задачу бинарной классификации при помощи написанного Вами дерева, а также леса из sklearn, а после интерпретировать лучшие модели. Чуть точнее
#
# - Извлечь данные из базы данных;
# - Предобработать датасет;
# - Обучить собственный класс DT, а также RF из `sklearn` в как базовом варианте (гиперпараметры по умолчанию), так и с подбором гиперпараметров;
# - Интерпретировать алгоритмы при помощи LIME или SHAP.
#
#
# ### **Оценивание:**
#
# - Как всегда оцениваются как код, так и ответы на вопросы. Если нет одного и/или другого, то часть баллов за соответствующее задание без колебаний снимается.
# - Брать код из открытых источников позволительно. Следование культуре цитирования **обязательно.**
# - Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов.
# - Неэффективная реализация кода может негативно отразиться на оценке.
#
# ### **Формат сдачи:**
# Задания сдаются через  anytask. Посылка должна содержать:
# * Ноутбук в формате ipynb
# * Модуль hw4_code_pro.py
#
#
# ### **Баллы:**
#
# Суммарно за задание можно получить 10 основных баллов и 1 бонусный балло.
#
# Оценка за ДЗ = min{ваш балл, 10}
#
# Мягкий дедлайн: 29 января 23:59
#
# **Продуктивной и интересной вам работы!**

# %%
import pandas as pd
# Out:
# /Users/ivanbogush/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# !pip install optuna
# !pip install lime
# !pip install shap
# !pip install psycopg2-binary
# Out:
# Requirement already satisfied: optuna in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (4.7.0)
# Requirement already satisfied: alembic>=1.5.0 in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from optuna) (1.18.4)
# Requirement already satisfied: colorlog in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from optuna) (6.10.1)
# Requirement already satisfied: numpy in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from optuna) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from optuna) (22.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from optuna) (1.4.39)
# Requirement already satisfied: tqdm in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: tomli in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from alembic>=1.5.0->optuna) (2.0.1)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from sqlalchemy>=1.4.2->optuna) (2.0.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.1)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: lime in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (0.2.0.1)
# Requirement already satisfied: matplotlib in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from lime) (3.7.0)
# Requirement already satisfied: numpy in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from lime) (1.24.4)
# Requirement already satisfied: scipy in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from lime) (1.10.0)
# Requirement already satisfied: tqdm in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from lime) (4.67.1)
# Requirement already satisfied: scikit-learn>=0.18 in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from lime) (1.0.2)
# Requirement already satisfied: scikit-image>=0.12 in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from lime) (0.19.3)
# Requirement already satisfied: networkx>=2.2 in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from scikit-image>=0.12->lime) (2.8.4)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from scikit-image>=0.12->lime) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from scikit-image>=0.12->lime) (2.26.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from scikit-image>=0.12->lime) (2021.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from scikit-image>=0.12->lime) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from scikit-image>=0.12->lime) (22.0)
# Requirement already satisfied: joblib>=0.11 in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from scikit-learn>=0.18->lime) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from scikit-learn>=0.18->lime) (2.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from matplotlib->lime) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from matplotlib->lime) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from matplotlib->lime) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from matplotlib->lime) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from matplotlib->lime) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from matplotlib->lime) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->lime) (1.16.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: shap in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (0.44.0)
# Requirement already satisfied: numpy in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from shap) (1.24.4)
# Requirement already satisfied: scipy in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from shap) (1.10.0)
# Requirement already satisfied: scikit-learn in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from shap) (1.0.2)
# Requirement already satisfied: pandas in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from shap) (2.3.3)
# Requirement already satisfied: tqdm>=4.27.0 in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from shap) (22.0)
# Requirement already satisfied: slicer==0.0.7 in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from shap) (0.0.7)
# Requirement already satisfied: numba in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from shap) (0.62.1)
# Requirement already satisfied: cloudpickle in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from shap) (2.0.0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from numba->shap) (0.45.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from pandas->shap) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.16.0)
# Requirement already satisfied: joblib>=0.11 in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from scikit-learn->shap) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (from scikit-learn->shap) (2.2.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: psycopg2-binary in /Users/ivanbogush/anaconda3/lib/python3.10/site-packages (2.9.11)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from matplotlib.colors import Colormap, ListedColormap
import pandas as pd
from sklearn.model_selection import train_test_split
import seaborn as sns
sns.set(style='whitegrid')

import psycopg2
import psycopg2.extras

import shap
import lime
import lime.lime_tabular

import optuna

import pickle

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **1. Решающие деревья своими руками (6 баллов)**

# %% [markdown]
# В этой части вам нужно реализовать свой класс для обучения решающего дерева в задаче бинарной классификации с возможностью обработки вещественных и категориальных признаков.
#
# Всего за часть вы можете получить 6 основных баллов и 1 бонусный.

# %% [markdown]
# ### **Задание 1. (1 балл)**
#
# Реализуйте функцию find_best_split из модуля hw4_code_pro.py

# %%
def find_best_split(feature_vector, target_vector):
    """
    Под критерием Джини здесь подразумевается следующая функция:
    $$Q(R) = -\frac {|R_l|}{|R|}H(R_l) -\frac {|R_r|}{|R|}H(R_r)$$,
    $R$ — множество объектов, $R_l$ и $R_r$ — объекты, попавшие в левое и правое поддерево,
     $H(R) = 1-p_1^2-p_0^2$, $p_1$, $p_0$ — доля объектов класса 1 и 0 соответственно.

    Указания:
    * Пороги, приводящие к попаданию в одно из поддеревьев пустого множества объектов, не рассматриваются.
    * В качестве порогов, нужно брать среднее двух сосдених (при сортировке) значений признака
    * Поведение функции в случае константного признака может быть любым.
    * При одинаковых приростах Джини нужно выбирать минимальный сплит.
    * За наличие в функции циклов балл будет снижен. Векторизуйте! :)

    :param feature_vector: вещественнозначный вектор значений признака
    :param target_vector: вектор классов объектов,  len(feature_vector) == len(target_vector)

    :return thresholds: отсортированный по возрастанию вектор со всеми возможными порогами, по которым объекты можно
     разделить на две различные подвыборки, или поддерева
    :return ginis: вектор со значениями критерия Джини для каждого из порогов в thresholds len(ginis) == len(thresholds)
    :return threshold_best: оптимальный порог (число)
    :return gini_best: оптимальное значение критерия Джини (число)
    """

    dict_results = {}   # Храним результаты
     # Храним отдельно значения ginis


    #Функция для расчета критерия gini

    def gini(left_split: np.array, right_split: np.array):
        
        p1,p0 = 0,0 
        size_left, size_right = np.size(left_split), np.size(right_split)
        size_full = size_left + size_right

        if size_left == 0 or size_right == 0:
            return np.inf

        #Расчет H(left_split) для левого поддерева 
        non_zero = np.count_nonzero(left_split)
        zeros = size_left - non_zero 

        p1 = non_zero/size_left 
        p0 = zeros/size_left 

        H_left = 1 - p1**2 - p0**2

        #Расчет H(right_split) для правого поддерева
        non_zero = np.count_nonzero(right_split)
        zeros = size_right - non_zero 

        p1 = non_zero/size_right 
        p0 = zeros/size_right 

        H_right = 1 - p1**2 - p0**2


        return - size_left/size_full * H_left - size_right/size_full * H_right 


    #Расчет трешхолдов 
    feature_vector_sort = sorted(feature_vector)
    thresholds = np.lib.stride_tricks.sliding_window_view(feature_vector_sort, 2).mean(axis=1) # Через скользящее
    ginis = []


    for thresh in thresholds:
        mask_left = feature_vector <= thresh
        mask_right = feature_vector > thresh
        left_split = target_vector[mask_left]
        right_split = target_vector[mask_right]
        g = gini(left_split, right_split)
        dict_results[thresh] = (left_split, right_split, g)
        ginis.append(g)

    ginis = np.array(ginis)
    idx_best = np.argmin(ginis)
    threshold_best = thresholds[idx_best]
    gini_best = ginis[idx_best]

    return thresholds, ginis, threshold_best, gini_best

# %% [markdown]
# ### **Задание 2. (0.25 балла)**
#
# Загрузите таблицу [students.csv](https://github.com/AnastasiyaMax/MLDS_ml_course_fall21/blob/main/hw/hw5_trees/students.csv). Это немного преобразованный датасет [User Knowledge](https://archive.ics.uci.edu/ml/datasets/User+Knowledge+Modeling).
#
# В наборе данных:
# - признаки объекта записаны в первых пяти столбцах;
# - в последнем записана целевая переменная (класс: 0 или 1).
#
# По этим данным, используя функцию из задания 1, постройте:
# - пять кривых "порог — значение критерия Джини" для всех пяти признаков;
# - scatter-графики "значение признака — класс" для всех пяти признаков;

# %%
def plot_line(ginis: np.array, threshholds: np.array, name: str):
    sns.lineplot(x=threshholds, y=ginis)
    plt.xlabel(name)
    plt.ylabel("Gini")

    return None

# %%
def plot_scatter_features(df):   # Сгенерировано нейронкой 
    """
    Строит scatter-графики 'значение признака — класс'
    для первых 5 признаков датасета.

    :param df: pd.DataFrame
    """

    features = df.iloc[:, :5]   # первые 5 столбцов — признаки
    target = df.iloc[:, -1]     # последний столбец — класс

    fig, axes = plt.subplots(2, 3, figsize=(15, 8))
    axes = axes.flatten()

    for i, feature in enumerate(features.columns):

        axes[i].scatter(features[feature], target, alpha=0.7)

        axes[i].set_title(feature)
        axes[i].set_xlabel("Feature value")
        axes[i].set_ylabel("Class")

    # скрываем лишнюю панель
    axes[5].axis('off')

    plt.tight_layout()
    plt.show()

# %%
df = pd.read_csv('students.csv')

# %%
for feature in df.columns[:5]:
    thresholds, ginis, threshold_best, gini_best = find_best_split(feature_vector=df[feature], target_vector=df['UNS'])
    plot_line(ginis=ginis, threshholds=thresholds, name=feature)
    plt.show()

# %%
plot_scatter_features(df=df)

# %%
thresholds, ginis, threshold_best, gini_best = find_best_split(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 thresholds, ginis, threshold_best, gini_best = find_best_split(a)
#
# NameError: name 'a' is not defined

# %% [markdown]
# ### **Задание 3. (0.6 балла)**
#
# Проанализируйтте построенные кривые. Ответьте на поставленные вопросы:
# - По какому признаку нужно производить деление выборки на два поддерева? (0.15 балла)
# - Согласуется ли этот результат с визуальной оценкой scatter-графиков? (0.15 балла)
# - Как бы охарактеризовали вид кривой для "хороших" признаков, по которым выборка делится почти идеально? (0.15 балла)
# - Чем отличаются кривые для признаков, по которым деление практически невозможно? (0.15 балла)

# %% [markdown]
# **Ответ:**
# 1) По признаку PEG
# 2) Да, лучшее разделение на два поддереве в признаке PEG будет при значение ~0,35
# 3) Принимают вид параболы
# 4) Имеют большое кол-во локальных минимумов, своего рода волнообразная структура

# %% [markdown]
# ### **Задание 4. (1.15 балла)**
#
# В некоторых случаях необходимо анализировать код исполненного класса на предмет оптимальности и ошибок. Потренируйтесь в этом!
#
# - Разберитесь с уже написанным кодом в классе DecisionTree модуля hw4_code_pro.py.
# - Найдите ошибки в реализации метода \_fit_node.
# - Напишите функцию \_predict_node.
#
# **Примечание 1:**
#
# Построение дерева осуществляется согласно базовому жадному алгоритму, предложенному в [лекции](https://github.com/esokolov/ml-course-hse/blob/master/2020-fall/lecture-notes/lecture07-trees.pdf) в разделе «Построение дерева».
# - Для категориальных признаков выполняется преобразование, описанное в лекции в разделе «Учет категориальных признаков».
#
# **Примечание 2:**
#
# - Выбор лучшего разбиения необходимо производить по критерию Джини.
# - Критерий останова: все объекты в листе относятся к одному классу или ни по одному признаку нельзя разбить выборку, чтобы Джини упал
# - Ответ в листе: наиболее часто встречающийся класс в листе.

# %% [markdown]
# ### **Задание 5. (0.5 балла)**
#
# Протестируйте свое решающее дерево на датасете [mushrooms](https://archive.ics.uci.edu/ml/datasets/Mushroom). Для этого:
#
# - Скачайте таблицу agaricus-lepiota.data (из [Data Folder](https://archive.ics.uci.edu/ml/machine-learning-databases/mushroom/))
# - Прочитайте данные с помощью pandas
# - Примените к каждому столбцу LabelEncoder (из sklearn), чтобы преобразовать строковые имена категорий в натуральные числа.
# - Обучите решающее дерево на половине случайно выбранных объектов (признаки в датасете категориальные)
# - Сделайте предсказания для оставшейся половины.
# - Вычислите accuracy (так как мы используем эту метрику и в силу задачи, нам не очень важно, что будет классом 1, а что — классом 0).
#
#
# У вас должно получиться значение accuracy, равное единице (или очень близкое к единице), и не очень глубокое дерево.

# %%
# Ваш код здесь

# %% [markdown]
# ### **Задание 6. (бонус, 1 балл)**
#
# Реализуйте в классе DecisionTree поддержку параметров max_depth, min_samples_split и min_samples_leaf по аналогии с DecisionTreeClassifier. Постройте графики зависимости качества предсказания в зависимости от этих параметров для набора данных tic-tac-toe (см. следующее задание).

# %% [markdown]
# ### **Задание 7. (2 балла)**
#
# **1. Загрузите следующие наборы данных** (напомним, что pandas умеет загружать файлы по url, в нашем случае это файл \*.data), предварительно ознакомившись с описанием признаков и целевой переменной в каждом из них (они записаны в Data Folder, в файле *.names):
# * [mushrooms](https://archive.ics.uci.edu/ml/datasets/Mushroom) (загрузили в предыдущем пункте, классы записаны в нулевом столбце),
# * [tic-tac-toe](https://archive.ics.uci.edu/dataset/101/tic+tac+toe+endgame) (классы записаны в последнем столбце)
# * [cars](https://archive.ics.uci.edu/ml/datasets/Car+Evaluation) (классы записаны в последнем столбце, считаем что unacc, acc — это класс 0, good, vgood — класс 1)
# * [nursery](https://archive.ics.uci.edu/ml/datasets/Nursery) (классы записаны в последнем столбце, считаем, что not_recom и recommend — класс 0, very_recom, priority, spec_prior — класс 1).
#
# **2. Закодируйте категориальные признаки, использовав LabelEncoder.** С помощью cross_val_score (cv=10) оцените accuracy на каждом из этих наборов данных следующих алгоритмов:
# * DecisionTree, считающий все признаки вещественными
# * DecisionTree, считающий все признаки категориальными
# * DecisionTree, считающий все признаки вещественными + one-hot-encoding всех признаков
# * DecisionTreeClassifier из sklearn. Запишите результат в pd.DataFrame (по строкам — наборы данных, по столбцам — алгоритмы).
#
# **Рекомендации:**
# * Чтобы cross_val_score вычисляла точность, нужно передать scoring=make_scorer(accuracy_score), обе фукнции из sklearn.metrics.
# * Если вам позволяет память (а она скорее всего позволяет), указывайте параметр sparse=False в OneHotEncoder (если вы, конечно, используете его). Иначе вам придется добиваться того, чтобы ваша реализация дерева умела работать с разреженными матрицами.

# %%
# Ваш код здесьﾟ

# %% [markdown]
# ### **Задание 8. (0.5 балла)**
#
# Проанализируйте результаты эксперимента. Ответьте на вопросы:
# - Одинаково ли для разных наборов данных ранжируются алгоритмы?
# Порассуждайте, почему так происходит.
# - Обратите внимание на значение признаков в разных наборах данных.
# Присутствует ли в результатах какая-то компонента случайности?
# - Если случайность есть, то можно ли повлиять на нее и улушить работу алгоритмов?

# %% [markdown]
# **Ответ:**

# %% [markdown]
# # **2. Задача бинарной классификации реализованным деревом (4 балла)**
#
# Всего за эту часть можно получить 4 балла.

# %% [markdown]
# В этом разделе вам необходимо решить задачу бинарной классификации самописным деревом и лесом из sklearn, а после интерпретировать лучшие модели. А именно:
#
# - Извлечь данные из базы данных;
# - Предобработать датасет;
# - Обучить собственный класс DT и RF из `sklearn` в как базовом варианте (гиперпараметры по умолчанию), так и с подбором гиперпараметров;
# - Интерпретировать алгоритмы при помощи LIME или SHAP.

# %% [markdown]
# ### **Познакомимся с задачей: постановка**
#
# У вас есть данные о полетах, обладающие следущими характеристиками:
# - Для **каждого** клиента известна краткая информация о самом человеке, о типе билета и о рейсе, а также оценки клиента различным аспектам полета.
# - Для **некоторых** клиентов известна их удовлетворенность полетом (satisfied или neutral or dissatisfied).
#
# По данным необходимо обучить модель, предсказывающую удовлетворенность клиентов полетом. Итоговые предсказания нужно сделать для клиентов, **для которых ответ неизвестен.**
#
# ### **Получение данных:**
#
# Компания держит все данные в облаке Яндекса в Postgresql. Данные разбиты на смысловые таблицы. Чтобы получить данные, вам необходимо подключиться к базе данных и добыть оттуда данные.

# %%
# !mkdir -p ~/.postgresql && \
wget "https://storage.yandexcloud.net/cloud-certs/CA.pem" \
    --output-document ~/.postgresql/root.crt && \
chmod 0600 ~/.postgresql/root.crt
# Out:
# zsh:1: command not found: wget

# %% [markdown]
# ### **Задание 9. Получение данных (0.5 балла)**
#
# - Подключитесь к БД при помощи `psycopg2.connect()`
# - Напишите SQL-запрос, объединяющий 3 нужные таблицы в одну
# - Результат запроса поместите в `pd.DataFrame`. Индексом получившегося датафрейма сделайте столбец 'id'.
#
# Список столбцов таблиц добудьте самостоятельно.
#
#
# **Примечание:**
#  Не забудьте закрыть соединение. Или открывайте соединение, используя менеджер контекста `with as`, который закроет его автоматически

# %% [markdown]
# ##### **Параметры соединения:**
# ```
# host=rc1b-70q90cunwkzx49mj.mdb.yandexcloud.net
# port=6432
# sslmode=verify-full
# dbname=db_flights
# user=mlhs_student
# password=mlhs_student
# target_session_attrs=read-write```
# ```

# %% [markdown]
# ##### **Схема БД**
#
# <img src="data:image/png;base64,..." alt="screens" width="600"/>

# %%
conn = psycopg2.connect(
    dbname="db_flights",
    user="mlhs_student",
    password="mlhs_student",
    host="rc1b-70q90cunwkzx49mj.mdb.yandexcloud.net",
    port="6432"
)

print("Connected!")
# Out:
# Connected!

# %%
cursor = conn.cursor()
conn.rollback()
cursor.execute("SELECT * FROM public.clients_bio")

rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Male', '48.0')
# (2, 'Female', '35.0')
# (3, 'Male', '41.0')
# (4, 'Male', '50.0')
# (5, 'Female', '49.0')
# (6, 'Male', '43.0')
# (7, 'Male', '43.0')
# (8, 'Female', '60.0')
# (9, 'Male', '50.0')
# (10, 'Female', '38.0')
# (11, 'Female', '28.0')
# (12, 'Female', '27.0')
# (13, 'Male', '24.0')
# (14, 'Male', '9.0')
# (15, 'Male', '52.0')
# (16, 'Male', '70.0')
# (17, 'Female', '48.0')
# (18, 'Female', '61.0')
# (19, 'Female', '11.0')
# (20, 'Female', '42.0')
# (21, 'Female', '14.0')
# (22, 'Female', '70.0')
# (23, 'Female', '56.0')
# (24, 'Male', '77.0')
# (25, 'Male', '51.0')
# (26, 'Male', '47.0')
# (27, 'Male', '50.0')
# (28, 'Male', '58.0')
# (29, 'Male', '320.0')
# (30, 'Male', '48.0')
# (31, 'Male', '35.0')
# (32, 'Male', '21.0')
# (33, 'Female', '33.0')
# (34, 'Female', '48.0')
# (35, 'Male', '39.0')
# (36, 'Female', '42.0')
# (37, 'Female', '54.0')
# (38, 'Female', '51.0')
# (39, 'Female', '46.0')
# (40, 'Male', '51.0')
# (41, 'Female', '54.0')
# (42, 'Female', '45.0')
# (43, 'Female', '54.0')
# (44, 'Male', '51.0')
# (45, 'Male', '56.0')
# (46, 'Female', '23.0')
# (47, 'Male', '24.0')
# (48, 'Female', '40.0')
# (49, 'Male', '20.0')
# (50, 'Male', '27.0')
# (51, 'Male', '44.0')
# (52, 'Female', '20.0')
# (53, 'Male', '37.0')
# (54, 'Male', '40.0')
# (55, 'Male', '36.0')
# (56, 'Female', '56.0')
# (57, 'Female', '56.0')
# (58, 'Female', '43.0')
# (59, 'Female', '41.0')
# (60, 'Male', '57.0')
# (61, 'Male', '42.0')
# (62, 'Male', '31.0')
# (63, 'Female', '37.0')
# (64, 'Male', '56.0')
# (65, 'Male', '24.0')
# (66, 'Male', '36.0')
# (67, 'Male', '50.0')
# (68, 'Male', '43.0')
# (69, 'Male', '52.0')
# (70, 'Female', '49.0')
# (71, 'Female', '47.0')
# (72, 'Male', '53.0')
# (73, 'Male', '70.0')
# (74, 'Female', '25.0')
# (75, 'Female', '184.0')
# (76, 'Male', '55.0')
# (77, 'Female', '72.0')
# (78, 'Male', '58.0')
# (79, 'Female', '70.0')
# (80, 'Female', '46.0')
# (81, 'Female', '19.0')
# (82, 'Male', '39.0')
# (83, 'Male', '58.0')
# (84, 'Female', '9.0')
# (85, 'Male', '53.0')
# (86, 'Female', '27.0')
# (87, 'Male', '65.0')
# (88, 'Female', '52.0')
# (89, 'Female', '53.0')
# (90, 'Male', '41.0')
# (91, 'Female', '32.0')
# (92, 'Female', '50.0')
# (93, 'Female', '43.0')
# (94, 'Male', '80.0')
# (95, 'Female', '7.0')
# (96, 'Female', '34.0')
# (97, 'Female', '18.0')
# (98, 'Male', '44.0')
# (99, 'Female', '52.0')
# (100, 'Female', '23.0')
# (101, 'Male', '44.0')
# (102, 'Female', '51.0')
# (103, 'Male', '44.0')
# (104, 'Male', '42.0')
# (105, 'Female', '55.0')
# (106, 'Male', '24.0')
# (107, 'Male', '47.0')
# (108, 'Male', '43.0')
# (109, 'Female', '72.0')
# (110, 'Female', '27.0')
# (111, 'Female', '39.0')
# (112, 'Female', '11.0')
# (113, 'Male', '54.0')
# (114, 'Female', '51.0')
# (115, 'Female', '12.0')
# (116, 'Female', '26.0')
# (117, 'Male', '39.0')
# (118, 'Male', '32.0')
# (119, 'Female', '37.0')
# (120, 'Male', '40.0')
# (121, 'Female', '38.0')
# (122, 'Male', '17.0')
# (123, 'Female', '33.0')
# (124, 'Female', '7.0')
# (125, 'Male', '21.0')
# (126, 'Male', '66.0')
# (127, 'Female', '68.0')
# (128, 'Male', '65.0')
# (129, 'Male', '67.0')
# (130, 'Female', '39.0')
# (131, 'Female', '28.0')
# (132, 'Male', '59.0')
# (133, 'Female', '26.0')
# (134, 'Female', '33.0')
# (135, 'Male', '56.0')
# (136, 'Female', '43.0')
# (137, 'Female', '45.0')
# (138, 'Male', '45.0')
# (139, 'Female', '69.0')
# (140, 'Male', '31.0')
# (141, 'Female', '55.0')
# (142, 'Male', '58.0')
# (143, 'Female', '39.0')
# (144, 'Female', '41.0')
# (145, 'Male', '16.0')
# (146, 'Male', '60.0')
# (147, 'Female', '47.0')
# (148, 'Female', '54.0')
# (149, 'Male', '37.0')
# (150, 'Male', '21.0')
# (151, 'Male', '36.0')
# (152, 'Female', '51.0')
# (153, 'Female', '35.0')
# (154, 'Female', '41.0')
# (155, 'Female', '17.0')
# (156, 'Female', '49.0')
# (157, 'Male', '60.0')
# (158, 'Male', '22.0')
# (159, 'Female', '46.0')
# (160, 'Female', '42.0')
# (161, 'Male', '20.0')
# (162, 'Male', '14.0')
# (163, 'Female', '64.0')
# (164, 'Male', '12.0')
# (165, 'Male', '29.0')
# (166, 'Female', '44.0')
# (167, 'Female', '66.0')
# (168, 'Male', '37.0')
# (169, 'Male', '35.0')
# (170, 'Female', '36.0')
# (171, 'Female', '49.0')
# (172, 'Male', '37.0')
# (173, 'Female', '57.0')
# (174, 'Female', '39.0')
# (175, 'Male', '36.0')
# (176, 'Female', '56.0')
# (177, 'Female', '10.0')
# (178, 'Male', '28.0')
# (179, 'Female', '36.0')
# (180, 'Male', '56.0')
# (181, 'Female', '56.0')
# (182, 'Male', '44.0')
# (183, 'Male', '26.0')
# (184, 'Male', '44.0')
# (185, 'Male', '49.0')
# (186, 'Male', '42.0')
# (187, 'Male', '36.0')
# (188, 'Male', '20.0')
# (189, 'Female', '42.0')
# (190, 'Male', '44.0')
# (191, 'Male', '35.0')
# (192, 'Male', '52.0')
# (193, 'Female', '50.0')
# (194, 'Female', '46.0')
# (195, 'Male', '36.0')
# (196, 'Male', '23.0')
# (197, 'Male', '56.0')
# (198, 'Male', '57.0')
# (199, 'Female', '60.0')
# (200, 'Female', '43.0')
# (201, 'Female', '43.0')
# (202, 'Male', '38.0')
# (203, 'Female', '27.0')
# (204, 'Female', '71.0')
# (205, 'Male', '59.0')
# (206, 'Male', '53.0')
# (207, 'Female', '40.0')
# (208, 'Female', '49.0')
# (209, 'Female', '69.0')
# (210, 'Female', '27.0')
# (211, 'Male', '22.0')
# (212, 'Female', '30.0')
# (213, 'Male', '16.0')
# (214, 'Male', '38.0')
# (215, 'Male', '34.0')
# (216, 'Female', '35.0')
# (217, 'Male', '48.0')
# (218, 'Male', '17.0')
# (219, 'Male', '31.0')
# (220, 'Male', '31.0')
# (221, 'Female', '36.0')
# (222, 'Female', '44.0')
# (223, 'Female', '16.0')
# (224, 'Male', '35.0')
# (225, 'Male', '29.0')
# (226, 'Male', '66.0')
# (227, 'Female', '56.0')
# (228, 'Female', '17.0')
# (229, 'Female', '33.0')
# (230, 'Female', '88.0')
# (231, 'Female', '47.0')
# (232, 'Female', '57.0')
# (233, 'Female', '38.0')
# (234, 'Male', '47.0')
# (235, 'Female', '16.0')
# (236, 'Male', '35.0')
# (237, 'Male', '7.0')
# (238, 'Female', '39.0')
# (239, 'Male', '44.0')
# (240, 'Female', '49.0')
# (241, 'Male', '22.0')
# (242, 'Male', '38.0')
# (243, 'Male', '22.0')
# (244, 'Male', '30.0')
# (245, 'Female', '29.0')
# (246, 'Male', '50.0')
# (247, 'Male', '11.0')
# (248, 'Male', '23.0')
# (249, 'Male', '20.0')
# (250, 'Female', '70.0')
# (251, 'Male', '66.0')
# (252, 'Female', '50.0')
# (253, 'Male', '39.0')
# (254, 'Male', '18.0')
# (255, 'Male', '26.0')
# (256, 'Male', '22.0')
# (257, 'Male', '58.0')
# (258, 'Male', '48.0')
# (259, 'Female', '55.0')
# (260, 'Male', '62.0')
# (261, 'Female', '61.0')
# (262, 'Male', '63.0')
# (263, 'Male', '43.0')
# (264, 'Female', '43.0')
# (265, 'Female', '49.0')
# (266, 'Male', '44.0')
# (267, 'Female', '40.0')
# (268, 'Male', '20.0')
# (269, 'Female', '55.0')
# (270, 'Female', '59.0')
# (271, 'Male', '35.0')
# (272, 'Male', '43.0')
# (273, 'Male', '53.0')
# (274, 'Female', '27.0')
# (275, 'Female', '29.0')
# (276, 'Female', '43.0')
# (277, 'Male', '40.0')
# (278, 'Female', '16.0')
# (279, 'Female', '23.0')
# (280, 'Male', '44.0')
# (281, 'Male', '51.0')
# (282, 'Male', '25.0')
# (283, 'Male', '40.0')
# (284, 'Female', '17.0')
# (285, 'Female', '45.0')
# (286, 'Female', '41.0')
# (287, 'Male', '55.0')
# (288, 'Female', '42.0')
# (289, 'Male', '51.0')
# (290, 'Male', '39.0')
# (291, 'Male', '54.0')
# (292, 'Female', '21.0')
# (293, 'Male', '52.0')
# (294, 'Male', '17.0')
# (296, 'Female', '47.0')
# (297, 'Female', '55.0')
# (298, 'Male', '52.0')
# (299, 'Male', '41.0')
# (300, 'Female', '24.0')
# (301, 'Male', '40.0')
# (302, 'Male', '52.0')
# (303, 'Male', '51.0')
# (304, 'Female', '43.0')
# (305, 'Male', '56.0')
# (306, 'Male', '26.0')
# (307, 'Female', '31.0')
# (308, 'Female', '56.0')
# (309, 'Male', '53.0')
# (310, 'Female', '60.0')
# (311, 'Male', '26.0')
# (312, 'Male', '22.0')
# (313, 'Male', '30.0')
# (314, 'Female', '59.0')
# (315, 'Female', '25.0')
# (316, 'Female', '44.0')
# (317, 'Female', '25.0')
# (318, 'Female', '29.0')
# (319, 'Female', '60.0')
# (320, 'Female', '21.0')
# (321, 'Male', '42.0')
# (322, 'Male', '49.0')
# (323, 'Male', '59.0')
# (324, 'Male', '21.0')
# (325, 'Female', '25.0')
# (326, 'Female', '31.0')
# (327, 'Female', '39.0')
# (328, 'Male', '56.0')
# (329, 'Male', '47.0')
# (330, 'Male', '46.0')
# (331, 'Male', '51.0')
# (332, 'Male', '44.0')
# (333, 'Female', '37.0')
# (334, 'Male', '26.0')
# (335, 'Female', '56.0')
# (336, 'Female', '40.0')
# (337, 'Male', '37.0')
# (338, 'Female', '57.0')
# (339, 'Female', '22.0')
# (340, 'Male', '16.0')
# (341, 'Female', '35.0')
# (342, 'Male', '27.0')
# (343, 'Female', '58.0')
# (344, 'Male', '8.0')
# (345, 'Male', '9.0')
# (346, 'Male', '68.0')
# (347, 'Female', '30.0')
# (348, 'Male', '56.0')
# (349, 'Female', '33.0')
# (350, 'Female', '25.0')
# (351, 'Male', '57.0')
# (352, 'Female', '7.0')
# (353, 'Female', '37.0')
# (354, 'Female', '51.0')
# (355, 'Male', '16.0')
# (356, 'Male', '50.0')
# (357, 'Female', '43.0')
# (358, 'Female', '39.0')
# (359, 'Male', '55.0')
# (360, 'Male', '27.0')
# (361, 'Male', '40.0')
# (362, 'Male', '24.0')
# (363, 'Female', '39.0')
# (364, 'Female', '33.0')
# (365, 'Female', '42.0')
# (366, 'Female', '35.0')
# (367, 'Male', '26.0')
# (368, 'Female', '46.0')
# (369, 'Female', '53.0')
# (370, 'Male', '49.0')
# (371, 'Male', '50.0')
# (372, 'Male', '50.0')
# (373, 'Male', '43.0')
# (374, 'Female', '39.0')
# (375, 'Male', '53.0')
# (376, 'Male', '54.0')
# (377, 'Female', '54.0')
# (378, 'Male', '41.0')
# (379, 'Female', '42.0')
# (380, 'Male', '45.0')
# (381, 'Female', '56.0')
# (382, 'Female', '46.0')
# (383, 'Female', '58.0')
# (384, 'Male', '43.0')
# (385, 'Female', '45.0')
# (386, 'Female', '58.0')
# (387, 'Female', '54.0')
# (388, 'Male', '69.0')
# (389, 'Female', '27.0')
# (390, 'Male', '58.0')
# (391, 'Female', '52.0')
# (392, 'Male', '52.0')
# (393, 'Male', '49.0')
# (394, 'Female', '35.0')
# (395, 'Female', '54.0')
# (396, 'Male', '35.0')
# (397, 'Female', '26.0')
# (398, 'Male', '52.0')
# (399, 'Male', '38.0')
# (400, 'Male', '23.0')
# (401, 'Female', '36.0')
# (402, 'Male', '42.0')
# (403, 'Female', '39.0')
# (404, 'Male', '39.0')
# (405, 'Male', '59.0')
# (406, 'Male', '36.0')
# (407, 'Female', '32.0')
# (408, 'Female', '47.0')
# (409, 'Male', '48.0')
# (410, 'Male', '57.0')
# (411, 'Female', '49.0')
# (412, 'Male', '58.0')
# (413, 'Male', '53.0')
# (414, 'Male', '51.0')
# (415, 'Female', '38.0')
# (416, 'Female', '44.0')
# (417, 'Female', '36.0')
# (418, 'Female', '48.0')
# (419, 'Male', '58.0')
# (420, 'Male', '36.0')
# (421, 'Female', '25.0')
# (422, 'Male', '42.0')
# (423, 'Female', '30.0')
# (424, 'Female', '51.0')
# (425, 'Male', '59.0')
# (426, 'Female', '39.0')
# (427, 'Female', '35.0')
# (428, 'Female', '40.0')
# (429, 'Female', '52.0')
# (430, 'Female', '24.0')
# (431, 'Male', '47.0')
# (432, 'Female', '46.0')
# (433, 'Male', '63.0')
# (434, 'Female', '27.0')
# (435, 'Male', '53.0')
# (436, 'Female', '60.0')
# (437, 'Male', '46.0')
# (438, 'Female', '63.0')
# (439, 'Female', '57.0')
# (440, 'Female', '66.0')
# (441, 'Male', '31.0')
# (442, 'Female', '14.0')
# (443, 'Male', '35.0')
# (444, 'Male', '48.0')
# (445, 'Female', '41.0')
# (446, 'Male', '46.0')
# (447, 'Female', '51.0')
# (448, 'Male', '48.0')
# (449, 'Male', '42.0')
# (450, 'Female', '32.0')
# (451, 'Female', '27.0')
# (452, 'Female', '39.0')
# (453, 'Male', '55.0')
# (455, 'Male', '47.0')
# (456, 'Female', '34.0')
# (457, 'Female', '48.0')
# (458, 'Male', '43.0')
# (459, 'Male', '59.0')
# (460, 'Female', '38.0')
# (461, 'Male', '41.0')
# (462, 'Female', '53.0')
# (463, 'Female', '44.0')
# (464, 'Female', '26.0')
# (465, 'Female', '30.0')
# (466, 'Female', '48.0')
# (467, 'Female', '47.0')
# (468, 'Female', '51.0')
# (469, 'Male', '48.0')
# (470, 'Male', '43.0')
# (471, 'Female', '56.0')
# (472, 'Male', '40.0')
# (473, 'Male', '57.0')
# (474, 'Female', '39.0')
# (475, 'Female', '59.0')
# (476, 'Female', '62.0')
# (477, 'Male', '57.0')
# (478, 'Female', '43.0')
# (479, 'Male', '28.0')
# (480, 'Female', '37.0')
# (481, 'Male', '55.0')
# (482, 'Female', '30.0')
# (483, 'Female', '34.0')
# (484, 'Male', '45.0')
# (485, 'Male', '39.0')
# (486, 'Male', '48.0')
# (487, 'Male', '23.0')
# (488, 'Male', '48.0')
# (489, 'Male', '20.0')
# (490, 'Female', '51.0')
# (491, 'Female', '57.0')
# (492, 'Male', '57.0')
# (493, 'Male', '59.0')
# (494, 'Female', '32.0')
# (495, 'Female', '59.0')
# (496, 'Female', '34.0')
# (497, 'Female', '41.0')
# (498, 'Female', '49.0')
# (499, 'Female', '57.0')
# (500, 'Male', '48.0')
# (501, 'Female', '38.0')
# (502, 'Male', '41.0')
# (503, 'Male', '38.0')
# (504, 'Male', '39.0')
# (505, 'Male', '52.0')
# (506, 'Male', '50.0')
# (507, 'Female', '36.0')
# (508, 'Female', '38.0')
# (509, 'Female', '57.0')
# (510, 'Female', '52.0')
# (511, 'Female', '40.0')
# (512, 'Male', '36.0')
# (513, 'Male', '56.0')
# (514, 'Male', '41.0')
# (515, 'Male', '21.0')
# (516, 'Male', '57.0')
# (517, 'Male', '50.0')
# (518, 'Female', '15.0')
# (519, 'Female', '34.0')
# (520, 'Female', '50.0')
# (521, 'Female', '59.0')
# (522, 'Female', '39.0')
# (523, 'Female', '48.0')
# (524, 'Female', '50.0')
# (525, 'Female', '30.0')
# (526, 'Female', '55.0')
# (527, 'Male', '38.0')
# (528, 'Female', '49.0')
# (529, 'Male', '54.0')
# (530, 'Female', '54.0')
# (531, 'Male', '52.0')
# (532, 'Male', '51.0')
# (533, 'Female', '38.0')
# (534, 'Male', '32.0')
# (535, 'Female', '42.0')
# (536, 'Female', '51.0')
# (537, 'Male', '23.0')
# (538, 'Female', '39.0')
# (539, 'Female', '46.0')
# (540, 'Male', '57.0')
# (541, 'Male', '54.0')
# (542, 'Male', '34.0')
# (543, 'Male', '53.0')
# (544, 'Male', '30.0')
# (545, 'Male', '39.0')
# (546, 'Female', '59.0')
# (547, 'Male', '50.0')
# (548, 'Female', '55.0')
# (549, 'Male', '32.0')
# (550, 'Female', '40.0')
# (551, 'Female', '44.0')
# (552, 'Female', '60.0')
# (553, 'Female', '57.0')
# (554, 'Female', '39.0')
# (555, 'Male', '31.0')
# (557, 'Female', '31.0')
# (558, 'Male', '42.0')
# (559, 'Female', '51.0')
# (560, 'Female', '32.0')
# (561, 'Male', '23.0')
# (562, 'Female', '59.0')
# (563, 'Female', '29.0')
# (564, 'Male', '49.0')
# (565, 'Male', '62.0')
# (566, 'Female', '52.0')
# (567, 'Male', '57.0')
# (568, 'Male', '40.0')
# (569, 'Female', '47.0')
# (570, 'Male', '40.0')
# (571, 'Male', '46.0')
# (572, 'Male', '64.0')
# (573, 'Female', '27.0')
# (574, 'Male', '25.0')
# (575, 'Female', '54.0')
# (576, 'Female', '68.0')
# (577, 'Female', '48.0')
# (578, 'Male', '37.0')
# (579, 'Male', '56.0')
# (580, 'Male', '46.0')
# (581, 'Male', '25.0')
# (582, 'Female', '33.0')
# (583, 'Female', '58.0')
# (584, 'Male', '25.0')
# (585, 'Male', '46.0')
# (586, 'Female', '50.0')
# (587, 'Female', '66.0')
# (588, 'Female', '40.0')
# (589, 'Male', '50.0')
# (590, 'Female', '56.0')
# (591, 'Female', '56.0')
# (592, 'Male', '55.0')
# (593, 'Female', '50.0')
# (594, 'Male', '42.0')
# (595, 'Male', '44.0')
# (596, 'Female', '176.0')
# (597, 'Female', '46.0')
# (598, 'Male', '56.0')
# (599, 'Female', '39.0')
# (600, 'Female', '56.0')
# (601, 'Female', '57.0')
# (602, 'Female', '58.0')
# (603, 'Female', '24.0')
# (604, 'Male', '47.0')
# (605, 'Female', '39.0')
# (606, 'Male', '46.0')
# (607, 'Female', '27.0')
# (608, 'Female', '30.0')
# (609, 'Male', '50.0')
# (610, 'Male', '23.0')
# (611, 'Male', '56.0')
# (612, 'Female', '48.0')
# (613, 'Male', '55.0')
# (614, 'Male', '40.0')
# (615, 'Female', '39.0')
# (616, 'Male', '27.0')
# (617, 'Female', '54.0')
# (618, 'Male', '27.0')
# (619, 'Male', '43.0')
# (620, 'Male', '58.0')
# (621, 'Male', '28.0')
# (622, 'Male', '43.0')
# (623, 'Male', '39.0')
# (624, 'Female', '39.0')
# (625, 'Male', '46.0')
# (626, 'Male', '51.0')
# (627, 'Male', '45.0')
# (628, 'Male', '42.0')
# (629, 'Male', '35.0')
# (630, 'Male', '40.0')
# (631, 'Female', '42.0')
# (632, 'Female', '47.0')
# (633, 'Female', '53.0')
# (634, 'Female', '39.0')
# (635, 'Male', '55.0')
# (636, 'Female', '57.0')
# (637, 'Male', '23.0')
# (638, 'Female', '40.0')
# (639, 'Male', '39.0')
# (640, 'Male', '40.0')
# (641, 'Male', '58.0')
# (642, 'Female', '52.0')
# (643, 'Female', '60.0')
# (644, 'Female', '49.0')
# (645, 'Male', '58.0')
# (646, 'Male', '52.0')
# (647, 'Female', '37.0')
# (648, 'Male', '21.0')
# (649, 'Male', '37.0')
# (650, 'Male', '58.0')
# (651, 'Male', '54.0')
# (652, 'Female', '23.0')
# (653, 'Male', '27.0')
# (654, 'Female', '30.0')
# (655, 'Male', '47.0')
# (656, 'Male', '39.0')
# (657, 'Female', '58.0')
# (658, 'Male', '48.0')
# (659, 'Male', '49.0')
# (660, 'Male', '57.0')
# (661, 'Female', '53.0')
# (662, 'Female', '48.0')
# (663, 'Female', '45.0')
# (664, 'Male', '58.0')
# (665, 'Female', '41.0')
# (666, 'Female', '26.0')
# (667, 'Female', '54.0')
# (668, 'Female', '46.0')
# (669, 'Male', '40.0')
# (670, 'Female', '50.0')
# (671, 'Female', '21.0')
# (672, 'Male', '44.0')
# (673, 'Female', '39.0')
# (674, 'Female', '41.0')
# (675, 'Female', '46.0')
# (676, 'Female', '52.0')
# (677, 'Female', '24.0')
# (678, 'Female', '54.0')
# (679, 'Male', '42.0')
# (680, 'Male', '46.0')
# (681, 'Female', '48.0')
# (682, 'Female', '27.0')
# (683, 'Male', '42.0')
# (684, 'Male', '32.0')
# (685, 'Male', '54.0')
# (686, 'Male', '34.0')
# (687, 'Male', '32.0')
# (688, 'Female', '42.0')
# (689, 'Female', '43.0')
# (690, 'Female', '59.0')
# (691, 'Male', '37.0')
# (692, 'Male', '26.0')
# (693, 'Female', '40.0')
# (694, 'Female', '39.0')
# (695, 'Male', '20.0')
# (696, 'Male', '22.0')
# (697, 'Male', '43.0')
# (698, 'Male', '18.0')
# (699, 'Female', '46.0')
# (700, 'Female', '61.0')
# (701, 'Male', '18.0')
# (702, 'Female', '34.0')
# (703, 'Male', '50.0')
# (704, 'Male', '55.0')
# (705, 'Female', '42.0')
# (706, 'Male', '45.0')
# (707, 'Male', '55.0')
# (708, 'Male', '38.0')
# (709, 'Female', '50.0')
# (710, 'Female', '40.0')
# (711, 'Male', '36.0')
# (712, 'Female', '52.0')
# (713, 'Male', '54.0')
# (714, 'Female', '37.0')
# (715, 'Male', '35.0')
# (716, 'Female', '37.0')
# (717, 'Female', '44.0')
# (718, 'Female', '47.0')
# (719, 'Female', '27.0')
# (720, 'Female', '51.0')
# (721, 'Female', '44.0')
# (722, 'Female', '58.0')
# (723, 'Female', '50.0')
# (724, 'Male', '45.0')
# (725, 'Male', '21.0')
# (726, 'Male', '56.0')
# (727, 'Female', '54.0')
# (728, 'Male', 'nan')
# (729, 'Female', '37.0')
# (730, 'Female', '41.0')
# (731, 'Female', '22.0')
# (732, 'Female', '55.0')
# (733, 'Female', '57.0')
# (734, 'Female', '39.0')
# (735, 'Female', '59.0')
# (736, 'Male', '56.0')
# (737, 'Female', '46.0')
# (738, 'Male', '44.0')
# (739, 'Female', '39.0')
# (740, 'Male', '32.0')
# (741, 'Male', '39.0')
# (742, 'Female', '46.0')
# (743, 'Female', '52.0')
# (744, 'Female', '43.0')
# (745, 'Female', '58.0')
# (746, 'Male', '44.0')
# (747, 'Male', '58.0')
# (748, 'Male', '54.0')
# (749, 'Male', '58.0')
# (750, 'Male', '55.0')
# (751, 'Female', '21.0')
# (752, 'Female', '47.0')
# (753, 'Female', '57.0')
# (754, 'Male', '56.0')
# (755, 'Female', '50.0')
# (756, 'Female', '44.0')
# (757, 'Female', '38.0')
# (758, 'Female', '20.0')
# (759, 'Female', '24.0')
# (760, 'Female', '37.0')
# (761, 'Male', '48.0')
# (762, 'Female', '37.0')
# (763, 'Female', '40.0')
# (764, 'Male', '43.0')
# (765, 'Male', '59.0')
# (766, 'Female', '60.0')
# (767, 'Female', '46.0')
# (768, 'Female', 'nan')
# (769, 'Male', '49.0')
# (770, 'Male', '300.0')
# (771, 'Male', '44.0')
# (772, 'Female', '73.0')
# (773, 'Male', '54.0')
# (774, 'Female', '56.0')
# (775, 'Female', '56.0')
# (776, 'Male', '55.0')
# (777, 'Female', '50.0')
# (778, 'Male', '42.0')
# (779, 'Male', '42.0')
# (780, 'Male', '60.0')
# (781, 'Male', '37.0')
# (782, 'Male', '39.0')
# (783, 'Female', '44.0')
# (784, 'Male', '24.0')
# (785, 'Male', '40.0')
# (786, 'Male', '22.0')
# (787, 'Female', '56.0')
# (788, 'Female', '30.0')
# (789, 'Female', '40.0')
# (790, 'Female', '47.0')
# (791, 'Female', '17.0')
# (792, 'Female', '41.0')
# (793, 'Female', '49.0')
# (794, 'Female', '22.0')
# (795, 'Female', '44.0')
# (796, 'Female', '37.0')
# (797, 'Male', '27.0')
# (798, 'Female', '48.0')
# (799, 'Male', '55.0')
# (800, 'Male', '25.0')
# (801, 'Female', '55.0')
# (802, 'Male', '47.0')
# (803, 'Female', '42.0')
# (804, 'Male', '44.0')
# (805, 'Male', '42.0')
# (806, 'Male', '42.0')
# (807, 'Female', '58.0')
# (808, 'Female', '50.0')
# (809, 'Male', '57.0')
# (810, 'Male', '26.0')
# (811, 'Female', '42.0')
# (812, 'Female', '22.0')
# (813, 'Male', '37.0')
# (814, 'Male', '30.0')
# (815, 'Male', '40.0')
# (816, 'Female', '48.0')
# (817, 'Male', '51.0')
# (818, 'Female', '37.0')
# (819, 'Female', '43.0')
# (820, 'Male', '41.0')
# (821, 'Female', '52.0')
# (822, 'Male', '47.0')
# (823, 'Male', '60.0')
# (824, 'Female', '54.0')
# (825, 'Female', '53.0')
# (826, 'Male', '47.0')
# (827, 'Male', '43.0')
# (828, 'Female', '61.0')
# (829, 'Female', '57.0')
# (830, 'Female', '27.0')
# (831, 'Female', '25.0')
# (832, 'Female', '38.0')
# (833, 'Male', '47.0')
# (834, 'Female', '20.0')
# (835, 'Male', '34.0')
# (836, 'Male', '39.0')
# (837, 'Female', '43.0')
# (838, 'Female', '35.0')
# (839, 'Female', '45.0')
# (840, 'Female', '51.0')
# (841, 'Female', '58.0')
# (842, 'Male', '52.0')
# (843, 'Female', '23.0')
# (844, 'Male', '52.0')
# (845, 'Male', '46.0')
# (846, 'Female', '39.0')
# (847, 'Male', '48.0')
# (848, 'Male', '63.0')
# (849, 'Female', '38.0')
# (850, 'Female', '54.0')
# (851, 'Male', '39.0')
# (852, 'Male', '49.0')
# (853, 'Male', '17.0')
# (854, 'Female', '18.0')
# (855, 'Male', '45.0')
# (856, 'Female', '58.0')
# (857, 'Male', '49.0')
# (858, 'Male', '40.0')
# (859, 'Female', '50.0')
# (860, 'Female', '56.0')
# (861, 'Male', '20.0')
# (862, 'Male', '55.0')
# (863, 'Female', '36.0')
# (864, 'Female', '39.0')
# (865, 'Male', '42.0')
# (866, 'Male', '44.0')
# (867, 'Female', '45.0')
# (868, 'Male', '57.0')
# (869, 'Male', '23.0')
# (870, 'Male', '44.0')
# (871, 'Male', '25.0')
# (872, 'Male', '43.0')
# (873, 'Female', '35.0')
# (874, 'Male', '20.0')
# (875, 'Female', '31.0')
# (876, 'Female', '20.0')
# (877, 'Female', '27.0')
# (878, 'Female', '37.0')
# (879, 'Female', '80.0')
# (880, 'Male', '43.0')
# (881, 'Male', '59.0')
# (882, 'Male', '49.0')
# (883, 'Female', '15.0')
# (884, 'Male', '39.0')
# (885, 'Female', '45.0')
# (886, 'Male', '47.0')
# (887, 'Female', '41.0')
# (888, 'Male', '42.0')
# (889, 'Male', '17.0')
# (890, 'Female', '55.0')
# (891, 'Female', '51.0')
# (892, 'Female', '24.0')
# (893, 'Female', '33.0')
# (894, 'Male', '26.0')
# (895, 'Male', '53.0')
# (896, 'Female', '39.0')
# (897, 'Female', '16.0')
# (898, 'Female', '40.0')
# (899, 'Male', '36.0')
# (900, 'Male', '40.0')
# (901, 'Female', '18.0')
# (902, 'Male', '47.0')
# (903, 'Female', '24.0')
# (904, 'Female', '51.0')
# (905, 'Female', '39.0')
# (906, 'Female', '42.0')
# (907, 'Male', '18.0')
# (908, 'Female', '37.0')
# (909, 'Female', '60.0')
# (910, 'Male', '35.0')
# (911, 'Female', '23.0')
# (912, 'Female', '47.0')
# (913, 'Female', '41.0')
# (914, 'Male', '77.0')
# (915, 'Female', '24.0')
# (916, 'Female', '61.0')
# (917, 'Female', '56.0')
# (918, 'Male', '32.0')
# (919, 'Male', '25.0')
# (920, 'Male', '49.0')
# (921, 'Male', '55.0')
# (922, 'Female', '60.0')
# (923, 'Male', '43.0')
# (924, 'Female', '41.0')
# (925, 'Female', '45.0')
# (926, 'Female', '25.0')
# (927, 'Male', '39.0')
# (928, 'Male', '62.0')
# (929, 'Male', '34.0')
# (930, 'Female', '26.0')
# (931, 'Female', '57.0')
# (932, 'Female', '61.0')
# (933, 'Female', '57.0')
# (934, 'Female', '42.0')
# (935, 'Male', '24.0')
# (936, 'Male', '44.0')
# (937, 'Male', '61.0')
# (938, 'Female', '56.0')
# (939, 'Female', '17.0')
# (940, 'Male', '39.0')
# (941, 'Female', '45.0')
# (942, 'Male', '46.0')
# (943, 'Male', '57.0')
# (944, 'Female', '46.0')
# (945, 'Female', '61.0')
# (946, 'Male', '56.0')
# (947, 'Female', '45.0')
# (948, 'Male', '70.0')
# (949, 'Female', '78.0')
# (950, 'Male', '36.0')
# (951, 'Female', '44.0')
# (952, 'Female', '57.0')
# (953, 'Male', '56.0')
# (954, 'Female', '56.0')
# (955, 'Female', '35.0')
# (956, 'Female', '21.0')
# (957, 'Female', '17.0')
# (958, 'Male', '56.0')
# (959, 'Female', '74.0')
# (960, 'Male', '48.0')
# (961, 'Male', '33.0')
# (962, 'Male', '40.0')
# (963, 'Male', '60.0')
# (964, 'Female', '44.0')
# (965, 'Male', '27.0')
# (966, 'Male', '17.0')
# (967, 'Male', '43.0')
# (968, 'Male', '57.0')
# (969, 'Female', '66.0')
# (970, 'Male', '57.0')
# (971, 'Female', '22.0')
# (972, 'Male', '44.0')
# (973, 'Female', '42.0')
# (974, 'Female', '37.0')
# (975, 'Female', '21.0')
# (976, 'Female', '54.0')
# (977, 'Male', '39.0')
# (978, 'Male', '37.0')
# (979, 'Female', '59.0')
# (980, 'Male', '53.0')
# (981, 'Male', '57.0')
# (982, 'Female', '30.0')
# (983, 'Female', '48.0')
# (984, 'Male', '37.0')
# (985, 'Female', '25.0')
# (986, 'Male', '38.0')
# (987, 'Male', '42.0')
# (988, 'Male', '25.0')
# (989, 'Female', '48.0')
# (990, 'Male', '40.0')
# (991, 'Male', '40.0')
# (992, 'Male', '55.0')
# (993, 'Male', '22.0')
# (994, 'Female', '38.0')
# (995, 'Male', '35.0')
# (996, 'Female', '34.0')
# (997, 'Male', '56.0')
# (998, 'Male', '37.0')
# (999, 'Male', '62.0')
# (1000, 'Female', '63.0')
# (1001, 'Male', '52.0')
# (1002, 'Female', '45.0')
# (1003, 'Male', '22.0')
# (1004, 'Female', '32.0')
# (1005, 'Female', '62.0')
# (1006, 'Male', '57.0')
# (1007, 'Male', '36.0')
# (1008, 'Male', '33.0')
# (1009, 'Female', '29.0')
# (1010, 'Female', '53.0')
# (1011, 'Male', '30.0')
# (1012, 'Male', '54.0')
# (1013, 'Female', '16.0')
# (1014, 'Male', '37.0')
# (1015, 'Male', '46.0')
# (1016, 'Female', '47.0')
# (1017, 'Male', '61.0')
# (1018, 'Female', '57.0')
# (1019, 'Male', '37.0')
# (1020, 'Female', '39.0')
# (1021, 'Female', '65.0')
# (1022, 'Male', '23.0')
# (1023, 'Male', '40.0')
# (1024, 'Female', '44.0')
# (1025, 'Female', '31.0')
# (1026, 'Female', '39.0')
# (1027, 'Male', '22.0')
# (1028, 'Male', '22.0')
# (1029, 'Female', '47.0')
# (1030, 'Female', '27.0')
# (1031, 'Female', '19.0')
# (1032, 'Female', '79.0')
# (1033, 'Male', '18.0')
# (1034, 'Female', '46.0')
# (1035, 'Male', '17.0')
# (1036, 'Female', '40.0')
# (1037, 'Male', '37.0')
# (1038, 'Female', '34.0')
# (1039, 'Male', '27.0')
# (1040, 'Male', '47.0')
# (1041, 'Female', '71.0')
# (1042, 'Male', '37.0')
# (1043, 'Male', '39.0')
# (1044, 'Female', '30.0')
# (1046, 'Male', '37.0')
# (1047, 'Female', '45.0')
# (1048, 'Male', '27.0')
# (1049, 'Male', '35.0')
# (1050, 'Female', '69.0')
# (1051, 'Male', '16.0')
# (1052, 'Female', '68.0')
# (1053, 'Female', '20.0')
# (1054, 'Male', '18.0')
# (1055, 'Male', '59.0')
# (1056, 'Female', '38.0')
# (1057, 'Female', '67.0')
# (1058, 'Male', '62.0')
# (1059, 'Male', '25.0')
# (1060, 'Male', '24.0')
# (1061, 'Female', '67.0')
# (1062, 'Male', '69.0')
# (1063, 'Male', '67.0')
# (1064, 'Female', '31.0')
# (1065, 'Female', '42.0')
# (1066, 'Male', '28.0')
# (1067, 'Female', '27.0')
# (1068, 'Female', '24.0')
# (1069, 'Female', '67.0')
# (1070, 'Male', '54.0')
# (1071, 'Male', '24.0')
# (1072, 'Female', '53.0')
# (1073, 'Female', '38.0')
# (1074, 'Female', '63.0')
# (1075, 'Female', '12.0')
# (1076, 'Female', '53.0')
# (1077, 'Female', '55.0')
# (1078, 'Female', '20.0')
# (1079, 'Female', '58.0')
# (1080, 'Male', '41.0')
# (1081, 'Male', '62.0')
# (1082, 'Female', '15.0')
# (1083, 'Male', '22.0')
# (1084, 'Female', '59.0')
# (1085, 'Female', '31.0')
# (1086, 'Female', '50.0')
# (1087, 'Male', '52.0')
# (1088, 'Male', '35.0')
# (1089, 'Female', '46.0')
# (1090, 'Male', '8.0')
# (1091, 'Male', '65.0')
# (1092, 'Male', '68.0')
# (1093, 'Female', '57.0')
# (1094, 'Female', '52.0')
# (1095, 'Female', '61.0')
# (1096, 'Female', '25.0')
# (1097, 'Male', '13.0')
# (1098, 'Male', '11.0')
# (1099, 'Male', '52.0')
# (1100, 'Female', '28.0')
# (1101, 'Female', '46.0')
# (1102, 'Female', '16.0')
# (1103, 'Female', '22.0')
# (1104, 'Male', '16.0')
# (1105, 'Male', '30.0')
# (1106, 'Male', '14.0')
# (1107, 'Female', '24.0')
# (1108, 'Female', '51.0')
# (1109, 'Female', '20.0')
# (1110, 'Female', '10.0')
# (1111, 'Female', '38.0')
# (1112, 'Female', '26.0')
# (1113, 'Male', '64.0')
# (1114, 'Female', '46.0')
# (1115, 'Male', '15.0')
# (1116, 'Male', '59.0')
# (1117, 'Male', '29.0')
# (1118, 'Female', '69.0')
# (1119, 'Male', '33.0')
# (1120, 'Male', '58.0')
# (1121, 'Male', '47.0')
# (1122, 'Female', '15.0')
# (1123, 'Female', '42.0')
# (1124, 'Male', '23.0')
# (1125, 'Male', '22.0')
# (1126, 'Female', '32.0')
# (1127, 'Male', '19.0')
# (1128, 'Female', '7.0')
# (1129, 'Female', '36.0')
# (1130, 'Female', '15.0')
# (1131, 'Male', '48.0')
# (1132, 'Female', '24.0')
# (1134, 'Female', '23.0')
# (1135, 'Female', '36.0')
# (1136, 'Male', '28.0')
# (1137, 'Male', '44.0')
# (1138, 'Male', '70.0')
# (1139, 'Male', '61.0')
# (1140, 'Female', '40.0')
# (1141, 'Male', '17.0')
# (1142, 'Male', '36.0')
# (1143, 'Male', '28.0')
# (1144, 'Male', '60.0')
# (1145, 'Male', '27.0')
# (1146, 'Female', '64.0')
# (1147, 'Male', '47.0')
# (1148, 'Male', '34.0')
# (1149, 'Female', '63.0')
# (1150, 'Female', '15.0')
# (1151, 'Male', '40.0')
# (1152, 'Female', '41.0')
# (1153, 'Female', '63.0')
# (1154, 'Male', '52.0')
# (1155, 'Male', '53.0')
# (1156, 'Male', '69.0')
# (1157, 'Male', '26.0')
# (1158, 'Male', '25.0')
# (1159, 'Male', '33.0')
# (1160, 'Female', '22.0')
# (1161, 'Female', '35.0')
# (1162, 'Female', '12.0')
# (1163, 'Male', '68.0')
# (1164, 'Male', '56.0')
# (1165, 'Female', '55.0')
# (1166, 'Female', '31.0')
# (1167, 'Female', '13.0')
# (1168, 'Male', '31.0')
# (1169, 'Female', '41.0')
# (1170, 'Female', '59.0')
# (1171, 'Female', '70.0')
# (1172, 'Male', '58.0')
# (1173, 'Female', '29.0')
# (1174, 'Male', '12.0')
# (1175, 'Female', '55.0')
# (1176, 'Female', '61.0')
# (1177, 'Female', '38.0')
# (1178, 'Female', '19.0')
# (1179, 'Male', '48.0')
# (1180, 'Male', '28.0')
# (1181, 'Male', '48.0')
# (1182, 'Male', '41.0')
# (1183, 'Male', '60.0')
# (1184, 'Female', '45.0')
# (1185, 'Male', '36.0')
# (1186, 'Male', '69.0')
# (1187, 'Female', '30.0')
# (1188, 'Male', '34.0')
# (1189, 'Female', '13.0')
# (1190, 'Female', '33.0')
# (1191, 'Male', '14.0')
# (1192, 'Female', '27.0')
# (1193, 'Male', '35.0')
# (1194, 'Female', '51.0')
# (1195, 'Male', '15.0')
# (1196, 'Female', '9.0')
# (1197, 'Female', '7.0')
# (1198, 'Female', '7.0')
# (1199, 'Female', '56.0')
# (1200, 'Male', '43.0')
# (1201, 'Female', '35.0')
# (1202, 'Male', '25.0')
# (1203, 'Female', '44.0')
# (1204, 'Male', '18.0')
# (1205, 'Female', '54.0')
# (1206, 'Male', '27.0')
# (1207, 'Male', '42.0')
# (1208, 'Female', '69.0')
# (1209, 'Female', '18.0')
# (1210, 'Female', '53.0')
# (1211, 'Female', '35.0')
# (1212, 'Male', 'nan')
# (1213, 'Male', '41.0')
# (1214, 'Male', '54.0')
# (1215, 'Female', '31.0')
# (1216, 'Female', '58.0')
# (1217, 'Female', '39.0')
# (1218, 'Male', '10.0')
# (1219, 'Male', '20.0')
# (1220, 'Female', '26.0')
# (1221, 'Female', '14.0')
# (1222, 'Female', '45.0')
# (1223, 'Male', '58.0')
# (1224, 'Female', '51.0')
# (1225, 'Female', '65.0')
# (1226, 'Female', '67.0')
# (1227, 'Female', '41.0')
# (1228, 'Male', '20.0')
# (1229, 'Female', '42.0')
# (1230, 'Male', '34.0')
# (1231, 'Male', '41.0')
# (1232, 'Female', '61.0')
# (1233, 'Female', '56.0')
# (1234, 'Male', '33.0')
# (1235, 'Male', '39.0')
# (1236, 'Male', '23.0')
# (1237, 'Female', '51.0')
# (1238, 'Male', '52.0')
# (1239, 'Female', '22.0')
# (1240, 'Female', '51.0')
# (1241, 'Male', '16.0')
# (1242, 'Male', '54.0')
# (1243, 'Male', '9.0')
# (1244, 'Female', '56.0')
# (1245, 'Female', '15.0')
# (1246, 'Male', '24.0')
# (1247, 'Male', '48.0')
# (1248, 'Female', '29.0')
# (1249, 'Male', '11.0')
# (1250, 'Female', '40.0')
# (1251, 'Male', '28.0')
# (1252, 'Male', '44.0')
# (1253, 'Male', '69.0')
# (1254, 'Female', '41.0')
# (1255, 'Female', '61.0')
# (1256, 'Female', '17.0')
# (1257, 'Female', '9.0')
# (1258, 'Male', '23.0')
# (1259, 'Male', '47.0')
# (1260, 'Male', '38.0')
# (1261, 'Male', '63.0')
# (1262, 'Female', '49.0')
# (1263, 'Female', '47.0')
# (1264, 'Male', '37.0')
# (1265, 'Female', '52.0')
# (1266, 'Female', '52.0')
# (1267, 'Male', '19.0')
# (1268, 'Female', '60.0')
# (1269, 'Male', '32.0')
# (1270, 'Female', '40.0')
# (1271, 'Male', '8.0')
# (1272, 'Female', '51.0')
# (1273, 'Male', '11.0')
# (1274, 'Male', '10.0')
# (1275, 'Female', '38.0')
# (1276, 'Male', '68.0')
# (1277, 'Male', '52.0')
# (1278, 'Male', '14.0')
# (1279, 'Female', '37.0')
# (1280, 'Female', '42.0')
# (1281, 'Female', '16.0')
# (1282, 'Female', '11.0')
# (1283, 'Male', '44.0')
# (1284, 'Female', '40.0')
# (1285, 'Male', '25.0')
# (1286, 'Male', '11.0')
# (1287, 'Male', '37.0')
# (1288, 'Female', '7.0')
# (1289, 'Male', '68.0')
# (1290, 'Male', '45.0')
# (1291, 'Male', '35.0')
# (1292, 'Female', '21.0')
# (1293, 'Male', '61.0')
# (1294, 'Female', '40.0')
# (1295, 'Female', '18.0')
# (1296, 'Female', '28.0')
# (1297, 'Male', '59.0')
# (1298, 'Male', '55.0')
# (1299, 'Female', '34.0')
# (1300, 'Male', '20.0')
# (1301, 'Female', '11.0')
# (1302, 'Female', '68.0')
# (1303, 'Female', '53.0')
# (1304, 'Female', '60.0')
# (1305, 'Female', '62.0')
# (1306, 'Male', '44.0')
# (1307, 'Male', '53.0')
# (1308, 'Female', '33.0')
# (1309, 'Female', '18.0')
# (1310, 'Male', '55.0')
# (1311, 'Male', '42.0')
# (1312, 'Male', '55.0')
# (1313, 'Male', '45.0')
# (1314, 'Male', '272.0')
# (1315, 'Female', '25.0')
# (1316, 'Female', '39.0')
# (1317, 'Male', '49.0')
# (1318, 'Female', '44.0')
# (1319, 'Male', '53.0')
# (1320, 'Male', '54.0')
# (1321, 'Female', '34.0')
# (1322, 'Male', '33.0')
# (1323, 'Male', '60.0')
# (1324, 'Female', '48.0')
# (1325, 'Male', '39.0')
# (1326, 'Male', '36.0')
# (1327, 'Female', '59.0')
# (1328, 'Female', '47.0')
# (1329, 'Female', '34.0')
# (1330, 'Female', '41.0')
# (1331, 'Female', '37.0')
# (1332, 'Female', '47.0')
# (1333, 'Female', '24.0')
# (1334, 'Male', '45.0')
# (1335, 'Female', '58.0')
# (1336, 'Female', '23.0')
# (1337, 'Female', '57.0')
# (1338, 'Female', '43.0')
# (1339, 'Male', '59.0')
# (1340, 'Female', '35.0')
# (1341, 'Female', '44.0')
# (1342, 'Male', '38.0')
# (1343, 'Female', '45.0')
# (1344, 'Male', '44.0')
# (1345, 'Female', '52.0')
# (1346, 'Male', '58.0')
# (1347, 'Female', '60.0')
# (1348, 'Female', '30.0')
# (1349, 'Male', '58.0')
# (1350, 'Male', '39.0')
# (1351, 'Female', '56.0')
# (1352, 'Female', '60.0')
# (1353, 'Male', '41.0')
# (1354, 'Male', '34.0')
# (1355, 'Female', '39.0')
# (1356, 'Female', '47.0')
# (1357, 'Female', '32.0')
# (1358, 'Female', '63.0')
# (1359, 'Male', '17.0')
# (1360, 'Male', '60.0')
# (1361, 'Male', '34.0')
# (1362, 'Female', '38.0')
# (1363, 'Male', '42.0')
# (1364, 'Male', '49.0')
# (1365, 'Female', '60.0')
# (1366, 'Male', '56.0')
# (1367, 'Male', '50.0')
# (1368, 'Female', '68.0')
# (1369, 'Female', '52.0')
# (1370, 'Female', '38.0')
# (1371, 'Female', '20.0')
# (1372, 'Female', '27.0')
# (1373, 'Male', '46.0')
# (1374, 'Male', '44.0')
# (1375, 'Male', '47.0')
# (1376, 'Female', '38.0')
# (1377, 'Male', '38.0')
# (1378, 'Female', '36.0')
# (1379, 'Male', '36.0')
# (1380, 'Male', '50.0')
# (1381, 'Male', '26.0')
# (1382, 'Male', '37.0')
# (1383, 'Female', '23.0')
# (1384, 'Female', '52.0')
# (1385, 'Female', '14.0')
# (1386, 'Male', '50.0')
# (1387, 'Male', '49.0')
# (1388, 'Female', '56.0')
# (1389, 'Female', '45.0')
# (1390, 'Male', '34.0')
# (1391, 'Female', '8.0')
# (1392, 'Male', '46.0')
# (1393, 'Male', '10.0')
# (1394, 'Male', '54.0')
# (1395, 'Female', '24.0')
# (1396, 'Male', '29.0')
# (1397, 'Female', '63.0')
# (1398, 'Female', '45.0')
# (1399, 'Female', '20.0')
# (1400, 'Male', '33.0')
# (1401, 'Female', '70.0')
# (1402, 'Female', '47.0')
# (1403, 'Male', '44.0')
# (1404, 'Male', '7.0')
# (1405, 'Male', '57.0')
# (1406, 'Male', '37.0')
# (1407, 'Male', '49.0')
# (1408, 'Female', '21.0')
# (1409, 'Female', '53.0')
# (1410, 'Female', '38.0')
# (1411, 'Male', '57.0')
# (1412, 'Male', '20.0')
# (1413, 'Male', '39.0')
# (1414, 'Female', '56.0')
# (1415, 'Male', '28.0')
# (1416, 'Male', '15.0')
# (1417, 'Male', '56.0')
# (1418, 'Female', '12.0')
# (1419, 'Female', '66.0')
# (1420, 'Male', '58.0')
# (1421, 'Male', '11.0')
# (1422, 'Male', '7.0')
# (1423, 'Male', '60.0')
# (1424, 'Male', '59.0')
# (1425, 'Female', '33.0')
# (1426, 'Female', '54.0')
# (1427, 'Female', '30.0')
# (1428, 'Female', '45.0')
# (1429, 'Male', '45.0')
# (1430, 'Female', '53.0')
# (1431, 'Female', '32.0')
# (1432, 'Female', '37.0')
# (1433, 'Female', '40.0')
# (1434, 'Male', '28.0')
# (1435, 'Female', '52.0')
# (1436, 'Female', '35.0')
# (1437, 'Male', '62.0')
# (1438, 'Female', '37.0')
# (1439, 'Female', '31.0')
# (1440, 'Female', '51.0')
# (1441, 'Female', '44.0')
# (1442, 'Male', '43.0')
# (1443, 'Female', '47.0')
# (1444, 'Female', '54.0')
# (1445, 'Male', '56.0')
# (1446, 'Female', '30.0')
# (1447, 'Female', '26.0')
# (1448, 'Male', '51.0')
# (1449, 'Male', '48.0')
# (1450, 'Female', '46.0')
# (1451, 'Female', '47.0')
# (1452, 'Female', '53.0')
# (1453, 'Male', '32.0')
# (1454, 'Male', '53.0')
# (1455, 'Male', '24.0')
# (1456, 'Female', '38.0')
# (1457, 'Male', '37.0')
# (1458, 'Female', '32.0')
# (1459, 'Male', '56.0')
# (1460, 'Female', '59.0')
# (1461, 'Female', '35.0')
# (1462, 'Male', '49.0')
# (1463, 'Male', '34.0')
# (1464, 'Female', '19.0')
# (1465, 'Male', '40.0')
# (1466, 'Female', '63.0')
# (1467, 'Male', '49.0')
# (1468, 'Male', '34.0')
# (1469, 'Female', '621.0')
# (1470, 'Male', '19.0')
# (1471, 'Female', '11.0')
# (1472, 'Male', '64.0')
# (1473, 'Female', '54.0')
# (1474, 'Male', '13.0')
# (1475, 'Male', '47.0')
# (1476, 'Female', '18.0')
# (1477, 'Female', '62.0')
# (1478, 'Male', '28.0')
# (1479, 'Male', '49.0')
# (1480, 'Female', '42.0')
# (1481, 'Male', '61.0')
# (1482, 'Male', '14.0')
# (1483, 'Male', '43.0')
# (1484, 'Male', '50.0')
# (1485, 'Male', '33.0')
# (1486, 'Male', '22.0')
# (1487, 'Female', '66.0')
# (1488, 'Male', '45.0')
# (1489, 'Female', '54.0')
# (1490, 'Female', '24.0')
# (1491, 'Female', '54.0')
# (1492, 'Male', '26.0')
# (1493, 'Female', '15.0')
# (1494, 'Female', '49.0')
# (1495, 'Female', '47.0')
# (1496, 'Male', '39.0')
# (1497, 'Male', '55.0')
# (1498, 'Male', '20.0')
# (1499, 'Female', '27.0')
# (1500, 'Male', '59.0')
# (1501, 'Male', '70.0')
# (1502, 'Female', '15.0')
# (1503, 'Male', '62.0')
# (1504, 'Male', '45.0')
# (1505, 'Male', '64.0')
# (1506, 'Male', '42.0')
# (1507, 'Male', '51.0')
# (1508, 'Male', '33.0')
# (1509, 'Male', '30.0')
# (1510, 'Female', '22.0')
# (1511, 'Female', '21.0')
# (1512, 'Male', '50.0')
# (1513, 'Female', '38.0')
# (1514, 'Female', '46.0')
# (1515, 'Male', '44.0')
# (1516, 'Male', '36.0')
# (1517, 'Female', '24.0')
# (1518, 'Female', '27.0')
# (1519, 'Male', '25.0')
# (1520, 'Female', '53.0')
# (1521, 'Male', '30.0')
# (1522, 'Male', '57.0')
# (1523, 'Male', '50.0')
# (1524, 'Female', '48.0')
# (1525, 'Female', '210.0')
# (1526, 'Female', '47.0')
# (1527, 'Female', '13.0')
# (1528, 'Female', '38.0')
# (1529, 'Male', '42.0')
# (1530, 'Female', '40.0')
# (1531, 'Male', '40.0')
# (1532, 'Female', '43.0')
# (1533, 'Female', '46.0')
# (1534, 'Male', '43.0')
# (1535, 'Male', '34.0')
# (1536, 'Female', '26.0')
# (1537, 'Female', '30.0')
# (1538, 'Male', '90.0')
# (1539, 'Female', '31.0')
# (1540, 'Male', '39.0')
# (1541, 'Male', '53.0')
# (1542, 'Male', '96.0')
# (1543, 'Male', '63.0')
# (1544, 'Female', '45.0')
# (1545, 'Female', '40.0')
# (1546, 'Male', '31.0')
# (1547, 'Male', '54.0')
# (1548, 'Male', '38.0')
# (1549, 'Male', '70.0')
# (1550, 'Female', '61.0')
# (1551, 'Male', '28.0')
# (1552, 'Female', '25.0')
# (1553, 'Female', '68.0')
# (1554, 'Female', '63.0')
# (1555, 'Female', '25.0')
# (1556, 'Female', '64.0')
# (1557, 'Female', '39.0')
# (1558, 'Male', '40.0')
# (1559, 'Female', '24.0')
# (1560, 'Female', '52.0')
# (1561, 'Male', '53.0')
# (1562, 'Male', '22.0')
# (1563, 'Male', '67.0')
# (1564, 'Female', '62.0')
# (1565, 'Male', '60.0')
# (1566, 'Female', '56.0')
# (1567, 'Female', '52.0')
# (1568, 'Female', '46.0')
# (1569, 'Female', '45.0')
# (1570, 'Male', '31.0')
# (1571, 'Female', '44.0')
# (1572, 'Female', '25.0')
# (1573, 'Male', '22.0')
# (1574, 'Female', '32.0')
# (1575, 'Male', '39.0')
# (1576, 'Male', '33.0')
# (1577, 'Female', '22.0')
# (1578, 'Female', '56.0')
# (1579, 'Male', '23.0')
# (1580, 'Female', '64.0')
# (1581, 'Female', '36.0')
# (1582, 'Male', '26.0')
# (1584, 'Male', '51.0')
# (1585, 'Male', '36.0')
# (1586, 'Male', '32.0')
# (1587, 'Male', '19.0')
# (1588, 'Male', '16.0')
# (1589, 'Male', '36.0')
# (1590, 'Female', '66.0')
# (1591, 'Male', '61.0')
# (1592, 'Female', '20.0')
# (1593, 'Female', '37.0')
# (1594, 'Female', '49.0')
# (1595, 'Female', '25.0')
# (1596, 'Female', '24.0')
# (1597, 'Male', '50.0')
# (1598, 'Male', '7.0')
# (1599, 'Male', '53.0')
# (1600, 'Female', '25.0')
# (1601, 'Female', '45.0')
# (1602, 'Female', '10.0')
# (1603, 'Male', '28.0')
# (1604, 'Male', '15.0')
# (1605, 'Female', '13.0')
# (1606, 'Female', '41.0')
# (1607, 'Male', '18.0')
# (1608, 'Female', '17.0')
# (1609, 'Male', '42.0')
# (1610, 'Male', '17.0')
# (1611, 'Female', '49.0')
# (1612, 'Male', '39.0')
# (1613, 'Male', '62.0')
# (1614, 'Male', '41.0')
# (1615, 'Female', '30.0')
# (1616, 'Female', '17.0')
# (1617, 'Male', '69.0')
# (1618, 'Male', '13.0')
# (1619, 'Male', '38.0')
# (1620, 'Male', '30.0')
# (1621, 'Male', 'nan')
# (1622, 'Female', '45.0')
# (1623, 'Male', '42.0')
# (1624, 'Female', '57.0')
# (1625, 'Female', '39.0')
# (1626, 'Female', '47.0')
# (1627, 'Female', '57.0')
# (1628, 'Female', '28.0')
# (1629, 'Male', '11.0')
# (1630, 'Female', '40.0')
# (1631, 'Female', '54.0')
# (1632, 'Male', '27.0')
# (1633, 'Male', '68.0')
# (1634, 'Female', '21.0')
# (1635, 'Female', '22.0')
# (1636, 'Male', '12.0')
# (1637, 'Female', '35.0')
# (1638, 'Female', '8.0')
# (1639, 'Female', '8.0')
# (1640, 'Female', '17.0')
# (1641, 'Male', '48.0')
# (1642, 'Female', '40.0')
# (1643, 'Male', '50.0')
# (1644, 'Male', '46.0')
# (1645, 'Female', '41.0')
# (1646, 'Male', '55.0')
# (1647, 'Male', '48.0')
# (1648, 'Female', '41.0')
# (1649, 'Male', '77.0')
# (1650, 'Female', '42.0')
# (1651, 'Female', '57.0')
# (1652, 'Male', '24.0')
# (1653, 'Female', '48.0')
# (1654, 'Female', '53.0')
# (1655, 'Male', '42.0')
# (1656, 'Female', '42.0')
# (1657, 'Male', '47.0')
# (1658, 'Female', '51.0')
# (1659, 'Female', '38.0')
# (1660, 'Male', '38.0')
# (1661, 'Male', '26.0')
# (1662, 'Male', '33.0')
# (1663, 'Female', '21.0')
# (1664, 'Male', '20.0')
# (1665, 'Male', '21.0')
# (1666, 'Male', '23.0')
# (1667, 'Male', '68.0')
# (1668, 'Male', '19.0')
# (1669, 'Male', '20.0')
# (1670, 'Male', '33.0')
# (1671, 'Female', '41.0')
# (1672, 'Female', '46.0')
# (1673, 'Female', '54.0')
# (1674, 'Female', '51.0')
# (1675, 'Female', '29.0')
# (1676, 'Female', '44.0')
# (1677, 'Female', '53.0')
# (1678, 'Male', '30.0')
# (1679, 'Male', '55.0')
# (1680, 'Male', '41.0')
# (1681, 'Female', '59.0')
# (1682, 'Female', '27.0')
# (1683, 'Male', '41.0')
# (1684, 'Female', '22.0')
# (1685, 'Male', '42.0')
# (1686, 'Male', '57.0')
# (1687, 'Female', '55.0')
# (1688, 'Male', '55.0')
# (1689, 'Female', '62.0')
# (1690, 'Female', '53.0')
# (1691, 'Male', '52.0')
# (1692, 'Male', '34.0')
# (1693, 'Male', '39.0')
# (1694, 'Female', '33.0')
# (1695, 'Female', '42.0')
# (1696, 'Female', '55.0')
# (1697, 'Male', '26.0')
# (1698, 'Male', '27.0')
# (1699, 'Male', '49.0')
# (1700, 'Female', '22.0')
# (1701, 'Male', '33.0')
# (1702, 'Female', '59.0')
# (1703, 'Female', '45.0')
# (1704, 'Female', '46.0')
# (1705, 'Male', '24.0')
# (1706, 'Female', '48.0')
# (1707, 'Female', '40.0')
# (1708, 'Male', '21.0')
# (1709, 'Male', '45.0')
# (1710, 'Female', '56.0')
# (1711, 'Female', '57.0')
# (1712, 'Female', '53.0')
# (1713, 'Male', '41.0')
# (1714, 'Female', '46.0')
# (1715, 'Female', '54.0')
# (1716, 'Male', '49.0')
# (1717, 'Male', '35.0')
# (1718, 'Female', '54.0')
# (1719, 'Male', '41.0')
# (1720, 'Female', '48.0')
# (1721, 'Female', '27.0')
# (1722, 'Female', '73.0')
# (1723, 'Female', '45.0')
# (1724, 'Male', '20.0')
# (1725, 'Female', '44.0')
# (1726, 'Female', '63.0')
# (1727, 'Male', '45.0')
# (1728, 'Female', '55.0')
# (1729, 'Female', '36.0')
# (1730, 'Male', '43.0')
# (1731, 'Female', '38.0')
# (1732, 'Male', '37.0')
# (1733, 'Female', '56.0')
# (1734, 'Male', '38.0')
# (1735, 'Male', '49.0')
# (1736, 'Male', '53.0')
# (1737, 'Male', '56.0')
# (1739, 'Male', '50.0')
# (1740, 'Female', '66.0')
# (1741, 'Male', '61.0')
# (1742, 'Male', '18.0')
# (1743, 'Male', '59.0')
# (1744, 'Male', '30.0')
# (1745, 'Male', '38.0')
# (1746, 'Female', '39.0')
# (1747, 'Female', '57.0')
# (1748, 'Female', '19.0')
# (1749, 'Male', '35.0')
# (1750, 'Female', '18.0')
# (1751, 'Male', '51.0')
# (1752, 'Female', '55.0')
# (1753, 'Male', '62.0')
# (1754, 'Female', '57.0')
# (1755, 'Male', '58.0')
# (1756, 'Male', '57.0')
# (1757, 'Male', '55.0')
# (1758, 'Female', '48.0')
# (1759, 'Female', '24.0')
# (1760, 'Female', '55.0')
# (1761, 'Male', '59.0')
# (1762, 'Female', '22.0')
# (1763, 'Male', '63.0')
# (1764, 'Male', '47.0')
# (1765, 'Male', '49.0')
# (1766, 'Male', '26.0')
# (1767, 'Female', '48.0')
# (1768, 'Male', '45.0')
# (1769, 'Male', '40.0')
# (1770, 'Male', '20.0')
# (1771, 'Female', '21.0')
# (1772, 'Male', '55.0')
# (1773, 'Female', '53.0')
# (1774, 'Female', '41.0')
# (1775, 'Female', '43.0')
# (1776, 'Male', '22.0')
# (1777, 'Male', '66.0')
# (1778, 'Female', '30.0')
# (1779, 'Female', '34.0')
# (1781, 'Female', '42.0')
# (1782, 'Female', '53.0')
# (1783, 'Female', '24.0')
# (1784, 'Female', '40.0')
# (1785, 'Female', '40.0')
# (1786, 'Male', '54.0')
# (1787, 'Male', '22.0')
# (1788, 'Male', '50.0')
# (1789, 'Male', '52.0')
# (1790, 'Female', '27.0')
# (1791, 'Male', '51.0')
# (1792, 'Female', '48.0')
# (1793, 'Male', '53.0')
# (1794, 'Female', '25.0')
# (1795, 'Male', '60.0')
# (1796, 'Female', '21.0')
# (1797, 'Male', '44.0')
# (1798, 'Female', '44.0')
# (1799, 'Male', '59.0')
# (1800, 'Male', '55.0')
# (1801, 'Male', '45.0')
# (1802, 'Male', '49.0')
# (1803, 'Male', '55.0')
# (1804, 'Male', '59.0')
# (1805, 'Female', '28.0')
# (1806, 'Female', '50.0')
# (1807, 'Male', '55.0')
# (1808, 'Female', '41.0')
# (1809, 'Male', '59.0')
# (1810, 'Female', '22.0')
# (1811, 'Male', '21.0')
# (1812, 'Female', '57.0')
# (1813, 'Male', '25.0')
# (1814, 'Female', '71.0')
# (1815, 'Male', '65.0')
# (1816, 'Female', '18.0')
# (1817, 'Male', '20.0')
# (1818, 'Female', '30.0')
# (1819, 'Female', '51.0')
# (1820, 'Female', '25.0')
# (1821, 'Female', '29.0')
# (1822, 'Female', '31.0')
# (1823, 'Female', '58.0')
# (1824, 'Male', '32.0')
# (1825, 'Female', '48.0')
# (1826, 'Female', '43.0')
# (1827, 'Female', '23.0')
# (1828, 'Female', '50.0')
# (1829, 'Male', '22.0')
# (1830, 'Female', '16.0')
# (1831, 'Female', '70.0')
# (1832, 'Female', '48.0')
# (1833, 'Female', '37.0')
# (1834, 'Male', '18.0')
# (1835, 'Male', '30.0')
# (1836, 'Female', '55.0')
# (1837, 'Male', '11.0')
# (1838, 'Female', '34.0')
# (1839, 'Male', '39.0')
# (1840, 'Male', '58.0')
# (1841, 'Female', '22.0')
# (1842, 'Male', '57.0')
# (1843, 'Male', '24.0')
# (1844, 'Female', '13.0')
# (1845, 'Male', '37.0')
# (1846, 'Male', '13.0')
# (1847, 'Male', '24.0')
# (1848, 'Male', '9.0')
# (1849, 'Female', '57.0')
# (1850, 'Male', 'nan')
# (1851, 'Female', '59.0')
# (1852, 'Male', '44.0')
# (1853, 'Female', '26.0')
# (1854, 'Male', '24.0')
# (1855, 'Female', '67.0')
# (1856, 'Male', '37.0')
# (1857, 'Female', '44.0')
# (1858, 'Female', '18.0')
# (1859, 'Female', '44.0')
# (1860, 'Male', '39.0')
# (1861, 'Male', '22.0')
# (1862, 'Male', '48.0')
# (1863, 'Female', '55.0')
# (1864, 'Male', '34.0')
# (1865, 'Female', '41.0')
# (1866, 'Female', '46.0')
# (1867, 'Male', '47.0')
# (1868, 'Female', '32.0')
# (1869, 'Female', '16.0')
# (1870, 'Male', '30.0')
# (1871, 'Female', '54.0')
# (1872, 'Female', '48.0')
# (1873, 'Male', '30.0')
# (1874, 'Male', '44.0')
# (1875, 'Female', '60.0')
# (1876, 'Male', '57.0')
# (1877, 'Female', '80.0')
# (1878, 'Male', '13.0')
# (1879, 'Female', '34.0')
# (1880, 'Female', '21.0')
# (1881, 'Female', '20.0')
# (1882, 'Male', '7.0')
# (1883, 'Male', '8.0')
# (1884, 'Female', '23.0')
# (1885, 'Male', '41.0')
# (1886, 'Female', '48.0')
# (1887, 'Male', '64.0')
# (1888, 'Male', '54.0')
# (1889, 'Female', '32.0')
# (1890, 'Male', '29.0')
# (1891, 'Male', '51.0')
# (1892, 'Male', '45.0')
# (1893, 'Female', '66.0')
# (1894, 'Female', '82.0')
# (1895, 'Male', '55.0')
# (1896, 'Male', '45.0')
# (1897, 'Female', '50.0')
# (1898, 'Male', '38.0')
# (1899, 'Male', '32.0')
# (1900, 'Male', '39.0')
# (1901, 'Male', '52.0')
# (1902, 'Male', '40.0')
# (1903, 'Female', '39.0')
# (1904, 'Male', '37.0')
# (1905, 'Female', '56.0')
# (1906, 'Female', '56.0')
# (1907, 'Female', '522.0')
# (1908, 'Male', '46.0')
# (1909, 'Female', '33.0')
# (1910, 'Male', '44.0')
# (1911, 'Male', '40.0')
# (1912, 'Male', '40.0')
# (1913, 'Male', '34.0')
# (1914, 'Male', '38.0')
# (1915, 'Female', '43.0')
# (1916, 'Male', '34.0')
# (1917, 'Female', '40.0')
# (1918, 'Male', '48.0')
# (1919, 'Female', '50.0')
# (1920, 'Female', '35.0')
# (1921, 'Male', '24.0')
# (1922, 'Female', '41.0')
# (1923, 'Female', '36.0')
# (1924, 'Male', '47.0')
# (1925, 'Female', '36.0')
# (1926, 'Female', '36.0')
# (1927, 'Female', '57.0')
# (1928, 'Female', '60.0')
# (1929, 'Male', '60.0')
# (1930, 'Male', '26.0')
# (1931, 'Male', '33.0')
# (1932, 'Male', '39.0')
# (1933, 'Male', '39.0')
# (1934, 'Female', '49.0')
# (1935, 'Female', '39.0')
# (1936, 'Male', '51.0')
# (1937, 'Female', '60.0')
# (1938, 'Male', '51.0')
# (1939, 'Male', '59.0')
# (1940, 'Female', '47.0')
# (1941, 'Male', '51.0')
# (1942, 'Female', '53.0')
# (1943, 'Female', '39.0')
# (1944, 'Male', '42.0')
# (1945, 'Male', '36.0')
# (1946, 'Female', '35.0')
# (1947, 'Female', '61.0')
# (1948, 'Male', '36.0')
# (1949, 'Male', '46.0')
# (1950, 'Female', '47.0')
# (1951, 'Female', '35.0')
# (1952, 'Male', 'nan')
# (1953, 'Female', '27.0')
# (1954, 'Female', '49.0')
# (1955, 'Female', '33.0')
# (1956, 'Male', '23.0')
# (1957, 'Male', '21.0')
# (1958, 'Male', '22.0')
# (1959, 'Female', '54.0')
# (1960, 'Female', '51.0')
# (1961, 'Female', '65.0')
# (1962, 'Male', '33.0')
# (1963, 'Male', '26.0')
# (1964, 'Female', '24.0')
# (1965, 'Male', '65.0')
# (1966, 'Male', '36.0')
# (1967, 'Female', '51.0')
# (1968, 'Female', '17.0')
# (1969, 'Male', '60.0')
# (1970, 'Male', '28.0')
# (1971, 'Female', '36.0')
# (1972, 'Female', '43.0')
# (1973, 'Male', '12.0')
# (1974, 'Male', '31.0')
# (1975, 'Female', '41.0')
# (1976, 'Male', '50.0')
# (1977, 'Female', '15.0')
# (1978, 'Male', '62.0')
# (1979, 'Female', '46.0')
# (1980, 'Male', '9.0')
# (1981, 'Male', '51.0')
# (1982, 'Male', '30.0')
# (1983, 'Male', '40.0')
# (1984, 'Male', '30.0')
# (1985, 'Male', '23.0')
# (1986, 'Male', '27.0')
# (1988, 'Male', '13.0')
# (1989, 'Female', '39.0')
# (1990, 'Male', '56.0')
# (1991, 'Male', '44.0')
# (1992, 'Male', '47.0')
# (1993, 'Male', '39.0')
# (1994, 'Female', '62.0')
# (1995, 'Male', '57.0')
# (1996, 'Male', '30.0')
# (1997, 'Male', '23.0')
# (1998, 'Female', '53.0')
# (1999, 'Male', '48.0')
# (2000, 'Female', '56.0')
# (2001, 'Female', '51.0')
# (2002, 'Male', '59.0')
# (2003, 'Female', '53.0')
# (2004, 'Female', '38.0')
# (2005, 'Female', '33.0')
# (2006, 'Female', '57.0')
# (2007, 'Male', '66.0')
# (2008, 'Male', '40.0')
# (2009, 'Male', '65.0')
# (2010, 'Male', '41.0')
# (2011, 'Female', '72.0')
# (2012, 'Male', '35.0')
# (2013, 'Female', '56.0')
# (2014, 'Female', 'nan')
# (2015, 'Female', '47.0')
# (2016, 'Female', '41.0')
# (2017, 'Female', '52.0')
# (2019, 'Male', '41.0')
# (2020, 'Male', '60.0')
# (2021, 'Female', '11.0')
# (2022, 'Female', '42.0')
# (2023, 'Female', '18.0')
# (2024, 'Female', '35.0')
# (2025, 'Female', '34.0')
# (2026, 'Male', '19.0')
# (2027, 'Female', '20.0')
# (2028, 'Male', '23.0')
# (2029, 'Female', '56.0')
# (2030, 'Female', '26.0')
# (2031, 'Female', '29.0')
# (2032, 'Male', '22.0')
# (2033, 'Male', '48.0')
# (2034, 'Female', '59.0')
# (2035, 'Male', '42.0')
# (2036, 'Female', '22.0')
# (2037, 'Male', '60.0')
# (2038, 'Female', '56.0')
# (2039, 'Female', '38.0')
# (2040, 'Female', '44.0')
# (2041, 'Female', '48.0')
# (2042, 'Male', '56.0')
# (2043, 'Female', '28.0')
# (2044, 'Female', '48.0')
# (2045, 'Male', '33.0')
# (2046, 'Male', '37.0')
# (2047, 'Female', '42.0')
# (2048, 'Male', '40.0')
# (2049, 'Male', '42.0')
# (2050, 'Male', '47.0')
# (2051, 'Male', '36.0')
# (2052, 'Male', '27.0')
# (2053, 'Male', '33.0')
# (2054, 'Male', '36.0')
# (2055, 'Female', '50.0')
# (2056, 'Female', '57.0')
# ...
# (129265, 'Female', '51.0')
# (129266, 'Male', '30.0')
# (129267, 'Female', '59.0')
# (129268, 'Male', '56.0')
# (129269, 'Male', '44.0')
# (129270, 'Female', '32.0')
# (129271, 'Male', '25.0')
# (129272, 'Female', '56.0')
# (129273, 'Male', '40.0')
# (129274, 'Male', '43.0')
# (129275, 'Male', '18.0')
# (129276, 'Male', '27.0')
# (129277, 'Female', '33.0')
# (129278, 'Male', '58.0')
# (129279, 'Male', '66.0')
# (129280, 'Female', '70.0')
# (129281, 'Male', '33.0')
# (129282, 'Male', '22.0')
# (129283, 'Female', '18.0')
# (129284, 'Female', '56.0')
# (129285, 'Male', '42.0')
# (129286, 'Female', '51.0')
# (129287, 'Female', '54.0')
# (129288, 'Female', '21.0')
# (129289, 'Male', '51.0')
# (129290, 'Female', '41.0')
# (129291, 'Female', '26.0')
# (129292, 'Female', '66.0')
# (129293, 'Female', '13.0')
# (129294, 'Female', '70.0')
# (129295, 'Female', '19.0')
# (129296, 'Female', '9.0')
# (129297, 'Female', '51.0')
# (129298, 'Female', '52.0')
# (129299, 'Female', '44.0')
# (129300, 'Female', '50.0')
# (129301, 'Female', '58.0')
# (129302, 'Male', '46.0')
# (129303, 'Male', '51.0')
# (129304, 'Male', '34.0')
# (129305, 'Female', '42.0')
# (129306, 'Female', '52.0')
# (129307, 'Female', '67.0')
# (129308, 'Male', '39.0')
# (129309, 'Female', '60.0')
# (129310, 'Male', '64.0')
# (129311, 'Female', '27.0')
# (129312, 'Male', '35.0')
# (129313, 'Male', '50.0')
# (129314, 'Male', '35.0')
# (129315, 'Male', '36.0')
# (129316, 'Male', '53.0')
# (129317, 'Male', '41.0')
# (129318, 'Female', '30.0')
# (129319, 'Female', '52.0')
# (129320, 'Female', '40.0')
# (129321, 'Female', '57.0')
# (129322, 'Female', '26.0')
# (129323, 'Male', '52.0')
# (129324, 'Female', '68.0')
# (129325, 'Female', '37.0')
# (129326, 'Female', '39.0')
# (129327, 'Female', '41.0')
# (129328, 'Male', '25.0')
# (129329, 'Male', '47.0')
# (129330, 'Male', '30.0')
# (129331, 'Female', '16.0')
# (129332, 'Female', '33.0')
# (129333, 'Male', '15.0')
# (129334, 'Male', '37.0')
# (129335, 'Female', '18.0')
# (129336, 'Female', '22.0')
# (129337, 'Female', '17.0')
# (129338, 'Female', '38.0')
# (129339, 'Male', '68.0')
# (129340, 'Male', '26.0')
# (129341, 'Female', '13.0')
# (129342, 'Female', '57.0')
# (129343, 'Male', '37.0')
# (129344, 'Male', '64.0')
# (129345, 'Male', '51.0')
# (129346, 'Female', '26.0')
# (129347, 'Female', '60.0')
# (129348, 'Male', '50.0')
# (129349, 'Male', '60.0')
# (129350, 'Female', '36.0')
# (129351, 'Male', '26.0')
# (129352, 'Male', '57.0')
# (129353, 'Male', '11.0')
# (129354, 'Female', '16.0')
# (129355, 'Male', '39.0')
# (129356, 'Female', '8.0')
# (129357, 'Male', '22.0')
# (129358, 'Male', '68.0')
# (129359, 'Male', '9.0')
# (129360, 'Male', '58.0')
# (129361, 'Male', '43.0')
# (129362, 'Male', '36.0')
# (129363, 'Male', '45.0')
# (129364, 'Male', '22.0')
# (129365, 'Female', '48.0')
# (129366, 'Male', '52.0')
# (129367, 'Female', '59.0')
# (129368, 'Female', '40.0')
# (129369, 'Male', '19.0')
# (129370, 'Female', '57.0')
# (129371, 'Male', '35.0')
# (129372, 'Male', '53.0')
# (129373, 'Male', '18.0')
# (129374, 'Male', '35.0')
# (129375, 'Female', '16.0')
# (129376, 'Female', '27.0')
# (129377, 'Male', '56.0')
# (129378, 'Male', '46.0')
# (129379, 'Female', '72.0')
# (129380, 'Female', '60.0')
# (129381, 'Female', '39.0')
# (129382, 'Male', '28.0')
# (129383, 'Female', '15.0')
# (129384, 'Female', '33.0')
# (129385, 'Female', '22.0')
# (129386, 'Female', '10.0')
# (129387, 'Female', '47.0')
# (129388, 'Male', '39.0')
# (129389, 'Male', '53.0')
# (129390, 'Female', '15.0')
# (129391, 'Female', '47.0')
# (129392, 'Male', '59.0')
# (129393, 'Male', '48.0')
# (129394, 'Male', '60.0')
# (129395, 'Male', '57.0')
# (129396, 'Female', '52.0')
# (129397, 'Male', '46.0')
# (129398, 'Female', '53.0')
# (129399, 'Female', '41.0')
# (129400, 'Male', '20.0')
# (129401, 'Female', '34.0')
# (129402, 'Female', '47.0')
# (129403, 'Female', '41.0')
# (129404, 'Male', '52.0')
# (129405, 'Female', '38.0')
# (129406, 'Male', '24.0')
# (129407, 'Male', '56.0')
# (129408, 'Male', '55.0')
# (129409, 'Female', '42.0')
# (129410, 'Female', '44.0')
# (129411, 'Female', '33.0')
# (129412, 'Female', '37.0')
# (129413, 'Male', '44.0')
# (129414, 'Male', '24.0')
# (129415, 'Male', '25.0')
# (129416, 'Male', '35.0')
# (129417, 'Male', '49.0')
# (129418, 'Female', '39.0')
# (129419, 'Male', '59.0')
# (129420, 'Male', '26.0')
# (129421, 'Male', '33.0')
# (129422, 'Male', '25.0')
# (129423, 'Female', '46.0')
# (129424, 'Male', '36.0')
# (129425, 'Female', '58.0')
# (129426, 'Male', '46.0')
# (129427, 'Male', '46.0')
# (129428, 'Female', '69.0')
# (129429, 'Female', '46.0')
# (129430, 'Male', '42.0')
# (129431, 'Male', '43.0')
# (129432, 'Male', '48.0')
# (129433, 'Male', '26.0')
# (129434, 'Male', '74.0')
# (129435, 'Male', '43.0')
# (129436, 'Male', '57.0')
# (129437, 'Female', '26.0')
# (129438, 'Male', '36.0')
# (129439, 'Female', '72.0')
# (129440, 'Female', '65.0')
# (129441, 'Female', '67.0')
# (129442, 'Male', '68.0')
# (129443, 'Female', '48.0')
# (129444, 'Male', '62.0')
# (129445, 'Male', '8.0')
# (129446, 'Male', '49.0')
# (129447, 'Female', '66.0')
# (129448, 'Male', '53.0')
# (129449, 'Female', '42.0')
# (129450, 'Female', '20.0')
# (129451, 'Female', '25.0')
# (129452, 'Female', '24.0')
# (129453, 'Female', '49.0')
# (129454, 'Female', '34.0')
# (129455, 'Female', '57.0')
# (129456, 'Female', '60.0')
# (129457, 'Female', '24.0')
# (129458, 'Male', '448.0')
# (129459, 'Female', '54.0')
# (129460, 'Male', '55.0')
# (129461, 'Female', '47.0')
# (129462, 'Male', '66.0')
# (129463, 'Male', '36.0')
# (129464, 'Male', '15.0')
# (129465, 'Male', '46.0')
# (129466, 'Female', '25.0')
# (129467, 'Male', '53.0')
# (129468, 'Male', '33.0')
# (129469, 'Male', '23.0')
# (129470, 'Female', '31.0')
# (129471, 'Female', '53.0')
# (129472, 'Male', '48.0')
# (129473, 'Male', '60.0')
# (129474, 'Male', '43.0')
# (129475, 'Male', '47.0')
# (129476, 'Male', '24.0')
# (129477, 'Female', '49.0')
# (129478, 'Female', '29.0')
# (129479, 'Male', '49.0')
# (129480, 'Female', '30.0')
# (129481, 'Male', '47.0')
# (129482, 'Male', '66.0')
# (129483, 'Male', '41.0')
# (129484, 'Female', '21.0')
# (129485, 'Female', '37.0')
# (129486, 'Male', '73.0')
# (129487, 'Female', '9.0')
# (129488, 'Female', '15.0')
# (129489, 'Male', '23.0')
# (129490, 'Male', '47.0')
# (129491, 'Female', '18.0')
# (129492, 'Female', '47.0')
# (129493, 'Female', '14.0')
# (129494, 'Male', '27.0')
# (129495, 'Female', '12.0')
# (129496, 'Male', '7.0')
# (129497, 'Female', '44.0')
# (129498, 'Male', '40.0')
# (129499, 'Female', '23.0')
# (129500, 'Female', '46.0')
# (129501, 'Female', '46.0')
# (129502, 'Female', '42.0')
# (129503, 'Male', '38.0')
# (129504, 'Female', '24.0')
# (129505, 'Female', '37.0')
# (129506, 'Female', '38.0')
# (129507, 'Female', '29.0')
# (129508, 'Female', '30.0')
# (129509, 'Female', '26.0')
# (129510, 'Female', '59.0')
# (129511, 'Female', '67.0')
# (129512, 'Male', '19.0')
# (129513, 'Female', '16.0')
# (129514, 'Male', '23.0')
# (129515, 'Female', '37.0')
# (129516, 'Male', '45.0')
# (129517, 'Female', '46.0')
# (129518, 'Male', '44.0')
# (129519, 'Female', '234.0')
# (129520, 'Female', '46.0')
# (129521, 'Female', '43.0')
# (129522, 'Female', '56.0')
# (129523, 'Male', '41.0')
# (129524, 'Male', '55.0')
# (129525, 'Male', '27.0')
# (129526, 'Male', '50.0')
# (129527, 'Male', '45.0')
# (129528, 'Female', '57.0')
# (129529, 'Male', '44.0')
# (129530, 'Female', '58.0')
# (129531, 'Female', '29.0')
# (129532, 'Female', '56.0')
# (129533, 'Female', '39.0')
# (129534, 'Male', '29.0')
# (129535, 'Female', '22.0')
# (129536, 'Female', '26.0')
# (129537, 'Female', '46.0')
# (129538, 'Male', '31.0')
# (129539, 'Female', '28.0')
# (129540, 'Male', '31.0')
# (129541, 'Female', '30.0')
# (129542, 'Female', '49.0')
# (129543, 'Female', '27.0')
# (129544, 'Male', '51.0')
# (129545, 'Male', '43.0')
# (129546, 'Male', '48.0')
# (129547, 'Female', '20.0')
# (129548, 'Male', '78.0')
# (129549, 'Male', '17.0')
# (129550, 'Female', '20.0')
# (129551, 'Female', '61.0')
# (129552, 'Male', '22.0')
# (129553, 'Female', '50.0')
# (129554, 'Male', '25.0')
# (129555, 'Male', '65.0')
# (129556, 'Female', '17.0')
# (129557, 'Female', '29.0')
# (129559, 'Female', '58.0')
# (129560, 'Male', '37.0')
# (129561, 'Female', '31.0')
# (129562, 'Female', '24.0')
# (129563, 'Female', '11.0')
# (129564, 'Female', '29.0')
# (129565, 'Female', '48.0')
# (129566, 'Male', '24.0')
# (129567, 'Female', '68.0')
# (129568, 'Male', '32.0')
# (129569, 'Female', '41.0')
# (129570, 'Female', '8.0')
# (129571, 'Female', '54.0')
# (129572, 'Female', '24.0')
# (129573, 'Female', '26.0')
# (129574, 'Male', '51.0')
# (129575, 'Female', '38.0')
# (129576, 'Female', '39.0')
# (129577, 'Male', '62.0')
# (129578, 'Male', '32.0')
# (129579, 'Male', '51.0')
# (129580, 'Male', '31.0')
# (129581, 'Male', '52.0')
# (129582, 'Female', '46.0')
# (129583, 'Female', '52.0')
# (129584, 'Male', '44.0')
# (129585, 'Male', '49.0')
# (129586, 'Male', '58.0')
# (129587, 'Female', '56.0')
# (129588, 'Male', '58.0')
# (129589, 'Female', '75.0')
# (129590, 'Male', '53.0')
# (129591, 'Female', '54.0')
# (129592, 'Female', '13.0')
# (129593, 'Male', '26.0')
# (129594, 'Male', '45.0')
# (129595, 'Male', '35.0')
# (129596, 'Female', '56.0')
# (129597, 'Female', '49.0')
# (129598, 'Female', '35.0')
# (129599, 'Female', '22.0')
# (129600, 'Male', '39.0')
# (129601, 'Female', '51.0')
# (129602, 'Female', '45.0')
# (129603, 'Male', '49.0')
# (129604, 'Male', '39.0')
# (129605, 'Male', '24.0')
# (129606, 'Male', '43.0')
# (129607, 'Female', '56.0')
# (129608, 'Male', '58.0')
# (129609, 'Female', '47.0')
# (129610, 'Female', '58.0')
# (129611, 'Male', '24.0')
# (129612, 'Female', '24.0')
# (129613, 'Female', '44.0')
# (129614, 'Male', '45.0')
# (129615, 'Male', '44.0')
# (129616, 'Male', '21.0')
# (129617, 'Female', '32.0')
# (129618, 'Male', '36.0')
# (129619, 'Female', '58.0')
# (129620, 'Female', '26.0')
# (129621, 'Male', '39.0')
# (129622, 'Female', '47.0')
# (129623, 'Female', '56.0')
# (129624, 'Male', '32.0')
# (129625, 'Female', '55.0')
# (129626, 'Female', '44.0')
# (129627, 'Female', 'nan')
# (129628, 'Female', '53.0')
# (129629, 'Female', '22.0')
# (129630, 'Male', '59.0')
# (129631, 'Female', '35.0')
# (129632, 'Male', '46.0')
# (129633, 'Male', '22.0')
# (129634, 'Male', '26.0')
# (129635, 'Male', '39.0')
# (129636, 'Male', '41.0')
# (129637, 'Male', '59.0')
# (129638, 'Male', '59.0')
# (129639, 'Male', '144.0')
# (129640, 'Female', '35.0')
# (129641, 'Male', '48.0')
# (129642, 'Female', '56.0')
# (129643, 'Female', '44.0')
# (129644, 'Male', '48.0')
# (129645, 'Female', '40.0')
# (129646, 'Male', '33.0')
# (129647, 'Male', '64.0')
# (129648, 'Female', '53.0')
# (129649, 'Female', '38.0')
# (129650, 'Male', '47.0')
# (129651, 'Female', '38.0')
# (129652, 'Male', '50.0')
# (129653, 'Female', '50.0')
# (129654, 'Female', '45.0')
# (129655, 'Female', '42.0')
# (129656, 'Male', '35.0')
# (129657, 'Male', '48.0')
# (129658, 'Female', '24.0')
# (129659, 'Male', '58.0')
# (129660, 'Male', '54.0')
# (129661, 'Male', '45.0')
# (129662, 'Female', '27.0')
# (129663, 'Male', '48.0')
# (129664, 'Male', '40.0')
# (129665, 'Female', '49.0')
# (129666, 'Male', '47.0')
# (129667, 'Male', '61.0')
# (129668, 'Female', '28.0')
# (129669, 'Male', '40.0')
# (129670, 'Female', '23.0')
# (129671, 'Male', '38.0')
# (129672, 'Male', '31.0')
# (129673, 'Male', '38.0')
# (129674, 'Female', '60.0')
# (129675, 'Female', '39.0')
# (129676, 'Female', '40.0')
# (129677, 'Male', '47.0')
# (129678, 'Female', '47.0')
# (129679, 'Male', '42.0')
# (129680, 'Male', '34.0')
# (129681, 'Male', '37.0')
# (129682, 'Male', '38.0')
# (129683, 'Male', '43.0')
# (129684, 'Male', '44.0')
# (129685, 'Female', '27.0')
# (129686, 'Male', '34.0')
# (129687, 'Female', '36.0')
# (129688, 'Male', '60.0')
# (129689, 'Male', '49.0')
# (129690, 'Male', '60.0')
# (129691, 'Male', '29.0')
# (129692, 'Female', '41.0')
# (129693, 'Male', '56.0')
# (129694, 'Male', '38.0')
# (129695, 'Male', '26.0')
# (129696, 'Male', '18.0')
# (129697, 'Female', '26.0')
# (129698, 'Male', '47.0')
# (129699, 'Female', '39.0')
# (129700, 'Male', '40.0')
# (129701, 'Female', '25.0')
# (129702, 'Female', '18.0')
# (129703, 'Male', '41.0')
# (129704, 'Female', '58.0')
# (129705, 'Male', '56.0')
# (129706, 'Female', '30.0')
# (129707, 'Male', '39.0')
# (129708, 'Male', '17.0')
# (129709, 'Male', '39.0')
# (129710, 'Female', '32.0')
# (129711, 'Female', '18.0')
# (129712, 'Male', '26.0')
# (129713, 'Male', '50.0')
# (129714, 'Female', '20.0')
# (129715, 'Female', '41.0')
# (129716, 'Male', '20.0')
# (129717, 'Female', '22.0')
# (129718, 'Female', '38.0')
# (129719, 'Male', '65.0')
# (129720, 'Female', '47.0')
# (129721, 'Female', '51.0')
# (129722, 'Female', '48.0')
# (129723, 'Female', '58.0')
# (129724, 'Female', '42.0')
# (129725, 'Female', '21.0')
# (129726, 'Female', '21.0')
# (129727, 'Female', '43.0')
# (129728, 'Male', '18.0')
# (129729, 'Female', '20.0')
# (129730, 'Female', '48.0')
# (129731, 'Female', '51.0')
# (129732, 'Male', '22.0')
# (129733, 'Male', '23.0')
# (129734, 'Female', '36.0')
# (129735, 'Female', '60.0')
# (129736, 'Female', '32.0')
# (129737, 'Male', '37.0')
# (129738, 'Male', '42.0')
# (129739, 'Female', '72.0')
# (129740, 'Male', '44.0')
# (129741, 'Male', '36.0')
# (129742, 'Female', '49.0')
# (129743, 'Female', '16.0')
# (129744, 'Male', '33.0')
# (129745, 'Male', '63.0')
# (129746, 'Female', '55.0')
# (129747, 'Male', '33.0')
# (129748, 'Male', '15.0')
# (129749, 'Male', '47.0')
# (129750, 'Male', '38.0')
# (129751, 'Male', '26.0')
# (129752, 'Female', '47.0')
# (129753, 'Female', '36.0')
# (129754, 'Male', '36.0')
# (129755, 'Female', '37.0')
# (129756, 'Female', '43.0')
# (129757, 'Male', '55.0')
# (129758, 'Female', '51.0')
# (129759, 'Female', '19.0')
# (129760, 'Male', '41.0')
# (129761, 'Female', '24.0')
# (129762, 'Male', '48.0')
# (129763, 'Male', '16.0')
# (129764, 'Female', '42.0')
# (129765, 'Male', '21.0')
# (129766, 'Male', '12.0')
# (129767, 'Female', '9.0')
# (129768, 'Male', '59.0')
# (129769, 'Male', '7.0')
# (129770, 'Female', '20.0')
# (129771, 'Male', '16.0')
# (129772, 'Female', '44.0')
# (129773, 'Female', '60.0')
# (129774, 'Male', '58.0')
# (129775, 'Male', '12.0')
# (129776, 'Female', '26.0')
# (129777, 'Female', '64.0')
# (129778, 'Male', '62.0')
# (129779, 'Male', '37.0')
# (129780, 'Female', '17.0')
# (129781, 'Female', '60.0')
# (129782, 'Female', '10.0')
# (129783, 'Male', '55.0')
# (129784, 'Female', '7.0')
# (129785, 'Female', '36.0')
# (129786, 'Male', '10.0')
# (129787, 'Female', '19.0')
# (129788, 'Female', '34.0')
# (129789, 'Male', '44.0')
# (129790, 'Male', '64.0')
# (129791, 'Female', '66.0')
# (129792, 'Male', '22.0')
# (129793, 'Male', '40.0')
# (129794, 'Female', '8.0')
# (129795, 'Male', '25.0')
# (129796, 'Female', '14.0')
# (129797, 'Male', '45.0')
# (129798, 'Female', '43.0')
# (129799, 'Female', '25.0')
# (129800, 'Male', '27.0')
# (129801, 'Female', '62.0')
# (129802, 'Male', '17.0')
# (129803, 'Female', '41.0')
# (129804, 'Male', '54.0')
# (129805, 'Female', '7.0')
# (129806, 'Female', '13.0')
# (129807, 'Male', '37.0')
# (129808, 'Female', '69.0')
# (129809, 'Female', '21.0')
# (129810, 'Male', '9.0')
# (129811, 'Female', '40.0')
# (129812, 'Male', '69.0')
# (129813, 'Male', '67.0')
# (129814, 'Male', '49.0')
# (129815, 'Female', '66.0')
# (129816, 'Female', '54.0')
# (129817, 'Male', '47.0')
# (129818, 'Male', '42.0')
# (129819, 'Female', '12.0')
# (129820, 'Female', '35.0')
# (129821, 'Female', '62.0')
# (129822, 'Female', '62.0')
# (129823, 'Male', '35.0')
# (129824, 'Female', '29.0')
# (129825, 'Female', '17.0')
# (129826, 'Male', '9.0')
# (129827, 'Male', '18.0')
# (129828, 'Male', '70.0')
# (129829, 'Male', '26.0')
# (129830, 'Male', '39.0')
# (129831, 'Female', '28.0')
# (129832, 'Female', '20.0')
# (129833, 'Female', '37.0')
# (129834, 'Male', '27.0')
# (129835, 'Male', '9.0')
# (129836, 'Female', '49.0')
# (129837, 'Male', '66.0')
# (129838, 'Female', '59.0')
# (129839, 'Male', '61.0')
# (129840, 'Male', '56.0')
# (129841, 'Female', '18.0')
# (129842, 'Male', '59.0')
# (129843, 'Female', '68.0')
# (129844, 'Male', '36.0')
# (129845, 'Female', '47.0')
# (129846, 'Male', '44.0')
# (129847, 'Female', '16.0')
# (129848, 'Female', '56.0')
# (129849, 'Female', '21.0')
# (129850, 'Female', '12.0')
# (129851, 'Male', '22.0')
# (129852, 'Male', '43.0')
# (129853, 'Female', '30.0')
# (129854, 'Female', '69.0')
# (129855, 'Female', '56.0')
# (129856, 'Female', '41.0')
# (129857, 'Male', '168.0')
# (129858, 'Female', '40.0')
# (129859, 'Female', '22.0')
# (129860, 'Male', '22.0')
# (129861, 'Female', '30.0')
# (129862, 'Female', '39.0')
# (129863, 'Male', '51.0')
# (129864, 'Female', '39.0')
# (129865, 'Male', '38.0')
# (129866, 'Male', '64.0')
# (129867, 'Female', '20.0')
# (129868, 'Male', '47.0')
# (129869, 'Female', '18.0')
# (129870, 'Male', '20.0')
# (129871, 'Female', '23.0')
# (129872, 'Female', '32.0')
# (129873, 'Female', '44.0')
# (129874, 'Female', '28.0')
# (129875, 'Female', '55.0')
# (129876, 'Male', '28.0')
# (129877, 'Male', '41.0')
# (129878, 'Male', '42.0')
# (129879, 'Male', '50.0')
# (129880, 'Female', '20.0')

# %%
assert df.shape == (129_549, 23)

# %% [markdown]
# Разобьем датасет на тренировочную и тестовую части. Тестовую часть отложим надолго -- до самого конца этого ноутбука.

# %%
df_train = df[df.satisfaction != '-']

df_train.head()

# %%
assert df_train.shape == (103_644, 23)

# %%
df_test = df[df.satisfaction == '-'].drop('satisfaction', axis=1)
df_test.head()

# %%
assert df_test.shape == (25_905, 22)

# %% [markdown]
# Разбиваем данные на трейн и валидацию. Не меняйте сид.

# %%
X_train, X_val, y_train, y_val = train_test_split(df_train.drop('satisfaction', axis=1), df_train.satisfaction, test_size=0.3, random_state=42)

# %%
assert X_train.shape == (72_550, 22)
assert X_val.shape == (31_094, 22)

# %% [markdown]
# ### **Задание 10 (0.25 балла)**
#
# - Преобразуйте числовые столбцы в `float`. Проверьте, есть ли в датафрейме пропуски и выбросы (в том числе в категориальных признаках)
# - Заполните пропуски в данных наиболее часто встречающимся значением.
# Помните про правильность заполнения.
# - Выведите основные статистики по числовым и категориальным столбцам таблицы
# - Сделайте **текстовый** вывод о распределениях значений признаков

# %%
# Ваш код здесь

# %% [markdown]
# `Ваш ответ здесь`

# %% [markdown]
# ### **Задание 11. (2 балла)**
#
# Осуществите предобработку датасета для обучения **полностью самостоятельно**, на основе вашего опыта из прошлых дз и изученной теории. Обязательно **комментируйте** каждое действие.
#
# **Примечание:**
#
# В данном задании ваша задача в том числе убедить ревьюера в достаточности предобработки.

# %%
# Ваш код здесь

# %% [markdown]
# ### **Задание 12. (0.25 балла)**
#
# - Обучите самописное дерево и Random Forest с базовыми гиперпараметрами. Выведите `f1-score`.

# %%
# Ваш код здесь

# %% [markdown]
# ### **Задание 13. (0.4 баллa)**
#
# - Попробуйте подобрать оптимальные гиперпараметры леса и дерева (если реализовали их в бонусе), используя [RandomizedSearchCV](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html).
# - Сравните качество полученных моделей и выберите лучшую. Лучшую модель сохраните в pickle.
#
# **Важно:**
#
# Хотя бы один из гиперпараметров перебирайте из распределения (например, `uniform` из `scipy.stats`)

# %%
# Ваш код здесь

# %% [markdown]
# ### **Задание 14. Анализ моделей (0.1 балла)**
#
# - Отобразите`feature_importances_` вашего лучшего случайного леса;
# - Проанализируйте, какие признаки оказались важными?

# %%
# Ваш код здесь

# %% [markdown]
# `Ваш ответ здесь. `

# %% [markdown]
# ### **Задание 15. (0.25 балла)**
# - Интерпретируйте важности признаков с помощью SHAP.
# - Опишите полученый график
#
# **Важно:** Для подсчета используйте 1000 случайных объектов, иначе не дождетесь за приемлемое время
#
# **Вам может помочь:** [Статья "Интерпретация моделей и диагностика сдвига данных: LIME, SHAP и Shapley Flow"](https://habr.com/ru/company/ods/blog/599573/) из блога ods.ai на Хабре

# %%
# Ваш код здесь

# %% [markdown]
# `Ваш ответ здесь. `

# %% [markdown]
# ### **Задание 16. (0.25 балла)**
#
# - Интерпретируйте важности признаков для одного прогноза с помощью LIME;
# - Опишите полученный график для выбранного наблюдения

# %%
# Ваш код здесь

# %% [markdown]
# `Ваш ответ здесь. `

# %% [markdown]
# # Обратная связь
#
# Расскажите, как вам это домашнее задание. Было ли оно полезным? Научились ли вы чему то? Насколько сложным по 10-балльной шкале оно вам показалось? Сколько времени у вас ушло на его выполнение? Что следовало ещё в него включить? Было ли что-то лишнее?
